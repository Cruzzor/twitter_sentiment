# %%
import re
# Tutorial about Python regular expressions: https://pymotw.com/2/re/ import string
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import nltk
import spacy
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Reference: https://www.kaggle.com/rohitsingh9990/ner-training-using-spacy-ensemble

# %%
BASE_PATH = '../../data/'

train_df = pd.read_csv(BASE_PATH + 'train.csv')
test_df = pd.read_csv( BASE_PATH + 'test.csv')
submission_df = pd.read_csv( BASE_PATH + 'sample_submission.csv')

train_df.dropna(inplace=True)

# %%
def save_model(output_dir, nlp, new_model_name):
    output_dir = f'../../models/{output_dir}'
    if output_dir is not None:        
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        nlp.meta["name"] = new_model_name
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

# %%
def train(train_data, output_dir, n_iter=20, model=None):
    """Load the model, set up the pipeline and train the entity recognizer."""
    ""
    if model is not None:
        nlp = spacy.load(output_dir)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")
    
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")
    
    # add labels
    for _, annotations in train_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # sizes = compounding(1.0, 4.0, 1.001)
        # batch up the examples using spaCy's minibatch
        if model is None:
            nlp.begin_training()
        else:
            nlp.resume_training()

        for itn in tqdm(range(n_iter)):
            random.shuffle(train_data)
            batches = minibatch(train_data, size=compounding(4.0, 500.0, 1.001))    
            losses = {}
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,   # dropout - make it harder to memorise data
                    losses=losses, 
                )
            
            print("Losses", losses)
    save_model(output_dir, nlp, 'st_ner')

# %%
def get_model_out_path(sentiment):
    model_out_path = None
    if sentiment == 'positive':
        model_out_path = 'model_pos'
    elif sentiment == 'negative':
        model_out_path = 'model_neg'
    else:
        model_out_path = 'model_neu'
    return model_out_path

# %%
def get_training_data(sentiment):
    train_data = []
    for index, row in train_df.iterrows():
        if row.sentiment == sentiment:
            selected_text = row.selected_text
            text = row.text
            start = text.find(selected_text)
            end = start + len(selected_text)
            train_data.append((text, {"entities": [[start, end, selected_text]]}))
    return train_data

# %% [markdown]
# ---------------

# %%
train_data = get_training_data("positive")
model_path = get_model_out_path("positive")

train(train_data, model_path, n_iter=2, model=None)
# Out:
# Created blank 'en' model
#   0%|                                                                                                                                                                            | 0/2 [05:18<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-4ebdee8fa037> in <module>
#       3
#       4 # for demo urpose i am just training the model for 2 iterations, feel free to experiment.
# ----> 5 train(train_data, model_path, n_iter=2, model=None)
#
# <ipython-input-9-dc28bc5b58bd> in train(train_data, output_dir, n_iter, model)
#      39             for batch in batches:
#      40                 texts, annotations = zip(*batch)
# ---> 41                 nlp.update(
#      42                     texts,  # batch of texts
#      43                     annotations,  # batch of annotations
#
# c:\users\mbergman\appdata\local\continuum\anaconda3\envs\twitter\lib\site-packages\spacy\language.py in update(self, docs, golds, drop, sgd, losses, component_cfg)
#     517             kwargs = component_cfg.get(name, {})
#     518             kwargs.setdefault("drop", drop)
# --> 519             proc.update(docs, golds, sgd=get_grads, losses=losses, **kwargs)
#     520             for key, (W, dW) in grads.items():
#     521                 sgd(W, dW, key=key)
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.begin_update()
#
# c:\users\mbergman\appdata\local\continuum\anaconda3\envs\twitter\lib\site-packages\thinc\check.py in checked_function(wrapped, instance, args, kwargs)
#     154                     raise ExpectedTypeError(check, ["Callable"])
#     155                 check(arg_id, fix_args, kwargs)
# --> 156         return wrapped(*args, **kwargs)
#     157
#     158     def arg_check_adder(func):
#
# c:\users\mbergman\appdata\local\continuum\anaconda3\envs\twitter\lib\site-packages\thinc\neural\_classes\affine.py in begin_update(self, input__BI, drop)
#      61     def begin_update(self, input__BI, drop=0.0):
#      62         input__BI = self.ops.xp.ascontiguousarray(input__BI)
# ---> 63         output__BO = self.predict(input__BI)
#      64
#      65         def finish_update(grad__BO, sgd=None):
#
# c:\users\mbergman\appdata\local\continuum\anaconda3\envs\twitter\lib\site-packages\thinc\check.py in checked_function(wrapped, instance, args, kwargs)
#     154                     raise ExpectedTypeError(check, ["Callable"])
#     155                 check(arg_id, fix_args, kwargs)
# --> 156         return wrapped(*args, **kwargs)
#     157
#     158     def arg_check_adder(func):
#
# c:\users\mbergman\appdata\local\continuum\anaconda3\envs\twitter\lib\site-packages\thinc\neural\_classes\affine.py in predict(self, input__BI)
#      54     @check.arg(1, has_shape(("nB", "nI")))
#      55     def predict(self, input__BI):
# ---> 56         output = self.ops.gemm(input__BI, self.W, trans2=True)
#      57         output += self.b
#      58         return output
#
# KeyboardInterrupt:

# %%
train_data
# Out:
# [('is hoping that she left her bb at home and didn`t lose it on the Metro',
#   {'entities': [[3, 9, 'hoping']]}),
#  ('Is happy...Skool just let out..! Today was my last day..! Yippee! R.I.P Jackson Tyler Morris..! Always Loved And Never Forgotten..!',
#   {'entities': [[103, 108, 'Loved']]}),
#  (' You`re cycling tho` that`s good. Healthy eating  Healthy and eating are a contradiction in terms.',
#   {'entities': [[1,
#      98,
#      'You`re cycling tho` that`s good. Healthy eating  Healthy and eating are a contradiction in terms.']]}),
#  ('_Y_Yankees changed my default pic since you`ve been showing so much love!',
#   {'entities': [[40, 73, 'you`ve been showing so much love!']]}),
#  (' wish i could  want to stay and play with u guys and enjoy a block party for once',
#   {'entities': [[51, 58, 'd enjoy']]}),
#  (' so glad, I hope yall make it back down near New Orleans',
#   {'entities': [[12, 16, 'hope']]}),
#  ('_aureole Oh my gosh, so cute!!!', {'entities': [[24, 30, 'cute!!']]}),
#  (' oooooooh I KNO  EEEEEEEKKKKKKK!  ROCKS!! >',
#   {'entities': [[31, 38, '!  ROCK']]}),
#  ('I`m so sleepy now...g`night! HAPPY MOTHER`S DAY to your Mother, Mama, Ma, Mommy (whatever you call them. LoL) from Mie!',
#   {'entities': [[29, 34, 'HAPPY']]}),
#  (' OMG, I get the $50 coupon from them all the time, do you?? I`m obsessed with their catalog when it comes in the mail',
#   {'entities': [[64, 72, 'obsessed']]}),
#  ('Happy Mothers Day to all the mom`s around  Hope you have a wonderful day!',
#   {'entities': [[0,
#      73,
#      'Happy Mothers Day to all the mom`s around  Hope you have a wonderful day!']]}),
#  ('*sigh* joe sings so purdy.  he makes me feel better',
#   {'entities': [[28, 51, 'he makes me feel better']]}),
#  ('The sun is shining brightly and the day has just begun! What`s in store? Wandering around les calanques maybe? Vin, definitely!',
#   {'entities': [[116, 127, 'definitely!']]}),
#  (' nice to meet ya!', {'entities': [[1, 5, 'nice']]}),
#  (' hey, have a great gig! We`ll have to do exchange of tracks via ze emayal  I`m all lost in loops right now and still writing ****',
#   {'entities': [[13, 18, 'great']]}),
#  (' I hope your mom is ok?', {'entities': [[3, 7, 'hope']]}),
#  ('_1993 Nope not yet  Within 10 working days from Thursday. It should be in before 2 weeks Wednesday. It`ll be in before that! I hope',
#   {'entities': [[127, 131, 'hope']]}),
#  ('#SanctuarySunday awesome news about the Leo Awards for Sanctuary, looks like they got 4 out of the 10 they were nomintated for, not bad!',
#   {'entities': [[17, 24, 'awesome']]}),
#  (' fantastic, love all things Krautrock',
#   {'entities': [[1, 11, 'fantastic,']]}),
#  (' Dinner done, shower done, now time to chill with block of chocolate',
#   {'entities': [[39, 44, 'chill']]}),
#  (' *waves back* Have a good day',
#   {'entities': [[14, 29, 'Have a good day']]}),
#  ('i can`t wait. 2 more days till happiness.',
#   {'entities': [[14, 41, '2 more days till happiness.']]}),
#  (' Thanks for the follow! (raises hand) I am',
#   {'entities': [[1, 23, 'Thanks for the follow!']]}),
#  (' There will be NO vidoe evidence!  I can`t wait, though. Now I just need 2 find a regular partner if I end up loving it!',
#   {'entities': [[35,
#      120,
#      'I can`t wait, though. Now I just need 2 find a regular partner if I end up loving it!']]}),
#  ('that was a fun bacontaco night', {'entities': [[11, 14, 'fun']]}),
#  ("'Viewers of my LinkedIn profiel also viewed Barack Obama, Francisco van Jole and Erwin Blom.' I`m in good company.",
#   {'entities': [[101, 105, 'good']]}),
#  (' Sounds lovely, hope you have a great day',
#   {'entities': [[1, 15, 'Sounds lovely,']]}),
#  ('Watched the White House dinner speech by Barack. He`s just so many kinds of awesome!',
#   {'entities': [[76, 84, 'awesome!']]}),
#  ('let`s make this last forever.', {'entities': [[16, 29, 'last forever.']]}),
#  (' Thanks for the support',
#   {'entities': [[1, 23, 'Thanks for the support']]}),
#  ('thanx ', {'entities': [[0, 5, 'thanx']]}),
#  ('http://twitpic.com/4wbn6 - my hubby and his adoarble baby brother',
#   {'entities': [[44, 52, 'adoarble']]}),
#  (' aww tessy wanna hug?', {'entities': [[1, 4, 'aww']]}),
#  ('haha. i love you too aimeeeeeee!', {'entities': [[8, 12, 'love']]}),
#  (' I really like pink after I saw her live while in the new T-MOBILE Advert',
#   {'entities': [[3, 14, 'really like']]}),
#  (' Dreams give rise to reality. When they said I wouldn`t   walk, my dream was to fly! Dream, Believe, Achieve!',
#   {'entities': [[1, 29, 'Dreams give rise to reality.']]}),
#  ('Red Rock for lunch with Colin.  and  couldn`t come.  IPA Junior freshly made! Yum yum yum.',
#   {'entities': [[75, 89, 'e! Yum yum yum']]}),
#  (' Goodmorning to you!Thank you so much for being so kind? The sun is out and I`m going to paint outside',
#   {'entities': [[19, 56, '!Thank you so much for being so kind?']]}),
#  ('Goodknight Twitterland! Happy Mother`s Day to all you blockhead mommas! Have a wonderful day!',
#   {'entities': [[24, 29, 'Happy']]}),
#  ('Star trek was SOOOOO AWESOME!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!Spock and Kirk were hillarious!!!  Im seeing it again. sooon.',
#   {'entities': [[21, 30, 'AWESOME!!']]}),
#  (' thank you for your comment', {'entities': [[1, 6, 'thank']]}),
#  ('At home about to go to sleep! Goodnight twitter world!',
#   {'entities': [[30, 54, 'Goodnight twitter world!']]}),
#  (' wish i was rollin with ya', {'entities': [[1, 5, 'wish']]}),
#  ('Also...     #travel #backpacking hope you enjoy our pics & videos',
#   {'entities': [[38, 45, 'you enj']]}),
#  ('is excited to see Samantha&Denise again  http://plurk.com/p/rr5id',
#   {'entities': [[3, 10, 'excited']]}),
#  (' No problem! These boxes are _made_ for undernourished IT professionals',
#   {'entities': [[1, 12, 'No problem!']]}),
#  ('Had a nice dinner with mom! I`ve started the chicken rolls. They are going to cook overnight. The rest I`ll do tomorrow.',
#   {'entities': [[0, 27, 'Had a nice dinner with mom!']]}),
#  ('  i just want to wish your mom a happy mothers day!',
#   {'entities': [[31, 51, 'a happy mothers day!']]}),
#  ('blogging..it`s my new passion',
#   {'entities': [[0, 29, 'blogging..it`s my new passion']]}),
#  ('Yay my friend Glen is here. Now i`m like this',
#   {'entities': [[0, 3, 'Yay']]}),
#  (' Thanks, Brad!  Looking forward to chatting with you too.. btw, like your new pix!',
#   {'entities': [[62, 82, ', like your new pix!']]}),
#  (' Did you see my message mandingo jr.!!..lol. I hope its music i`ll like.',
#   {'entities': [[39, 72, '.lol. I hope its music i`ll like.']]}),
#  (' Are you a night owl or what? Always on here as the same time as myself  Enjoy your scifi show.',
#   {'entities': [[73, 95, 'Enjoy your scifi show.']]}),
#  ('Happy Mothers Day  Breakfast With The Fam <33',
#   {'entities': [[0, 5, 'Happy']]}),
#  (' Woot freaking hoo, tho Mad World isn`t doing well on the iTunes top #100 chart.',
#   {'entities': [[1, 19, 'Woot freaking hoo,']]}),
#  ('Writing Mother`s Day cards for my mom and gran...  hurray!',
#   {'entities': [[51, 58, 'hurray!']]}),
#  (' bahaha i loook like kung fu panda when i wake up in the morning.',
#   {'entities': [[1, 7, 'bahaha']]}),
#  ('kellie: Its a major problem okay. alex: what is? Kellie: hahahahahahahaa your face',
#   {'entities': [[57, 72, 'hahahahahahahaa']]}),
#  (' YES!! I wanna come hang out with my H-TOWN gurl u know whats up!! haha  it`ll be bangin! We gotta hang out chick',
#   {'entities': [[67, 71, 'haha']]}),
#  ('he`s pretty cute.', {'entities': [[12, 17, 'cute.']]}),
#  ('I wish I was laying in the sand listening to the waves crash against the shore!!!',
#   {'entities': [[0, 8, 'I wish I']]}),
#  ('is off to Body Power Expo! Thanks to Mike at Performance Network for the free tix!',
#   {'entities': [[27, 33, 'Thanks']]}),
#  ('I had a super cool dream last night.  asked me and  to be on her show. Wooowww.  *hopes it will come true* )',
#   {'entities': [[69, 78, '. Wooowww']]}),
#  ('My gut says to replace $$$ appliances instead of repair, but I want to be smart with $. When I try repair, replace was the right choice.',
#   {'entities': [[74, 79, 'smart']]}),
#  ('oh that was good cake', {'entities': [[12, 16, 'good']]}),
#  ('   Happy mother`s day to your moms.', {'entities': [[3, 7, 'Happ']]}),
#  ('i`m yours - jason mraz....looking for an electric guitar  yay!!!1',
#   {'entities': [[58, 62, 'yay!']]}),
#  ("This weekend I started a 'Healthy Lifeestyle' - not Diet!     Let`s see how it goes - will keep ya posted on my progress.",
#   {'entities': [[26, 33, 'Healthy']]}),
#  (' lol! I don`t know! but you dont need the plant! I`ll give you a hug instead! Hugs!',
#   {'entities': [[65, 68, 'hug']]}),
#  (' have you watched Persepolis? Broken English is also nice for sundays',
#   {'entities': [[53, 57, 'nice']]}),
#  ('well Sunday the weather looks great gone take my bike to visite my mom on her day',
#   {'entities': [[16, 35, 'weather looks great']]}),
#  ('felï¿½z dia de madres  | happy mothers day',
#   {'entities': [[25, 30, 'happy']]}),
#  ('Ahhh i`m sqeaky clean and fresh. Even though i`m wearing dirty clothes  I love Two and a Half Men - it`s amazing!',
#   {'entities': [[0,
#      113,
#      'Ahhh i`m sqeaky clean and fresh. Even though i`m wearing dirty clothes  I love Two and a Half Men - it`s amazing!']]}),
#  ('_lopez I love you  kiss me!',
#   {'entities': [[7, 27, 'I love you  kiss me!']]}),
#  ('happy mothers day... *i love you mom...*',
#   {'entities': [[0, 40, 'happy mothers day... *i love you mom...*']]}),
#  ('. welcome to Twitter!!!    Love you!!!  Can`t wait to see you next month',
#   {'entities': [[27, 34, 'Love yo']]}),
#  ('  I told ya`ll I am a good girl. You can see my halo and everything',
#   {'entities': [[2,
#      67,
#      'I told ya`ll I am a good girl. You can see my halo and everything']]}),
#  ('Happiness comes from within...so the fact that it is a gray, rainy, Monday doesn`t bother me. Well, not too much.',
#   {'entities': [[68, 93, 'Monday doesn`t bother me.']]}),
#  (' ah its getting there  still a fair bit to go, but it`s coming together fairly well! aw  where are you from?',
#   {'entities': [[69, 84, 'er fairly well!']]}),
#  ('I had a great time at the surprise party! We got him good!',
#   {'entities': [[8, 18, 'great time']]}),
#  (' lol! Ahhh well its a good song', {'entities': [[1, 5, 'lol!']]}),
#  ('just watched JONAS. It was funny.',
#   {'entities': [[20, 33, 'It was funny.']]}),
#  ('wish all the mother in the flatworld have a happy & awesome mother`s day',
#   {'entities': [[52, 59, 'awesome']]}),
#  (' good morning misfit *passes you Tylenol*', {'entities': [[1, 5, 'good']]}),
#  (' ok, so I`m replying!  happy mothers day, indeed!',
#   {'entities': [[23, 28, 'happy']]}),
#  (' Where are u  miss you I hope you are doing well *sending big hugs*',
#   {'entities': [[1,
#      66,
#      'Where are u  miss you I hope you are doing well *sending big hugs']]}),
#  (' bit excited are u bradie lol', {'entities': [[5, 12, 'excited']]}),
#  ("Romantic evening in with papa murphys and 'battle BC' from the history channel",
#   {'entities': [[0,
#      78,
#      "Romantic evening in with papa murphys and 'battle BC' from the history channel"]]}),
#  ('omg   i found it  thnx', {'entities': [[0, 21, 'omg   i found it  thn']]}),
#  ('On a day like today. I am thankful for my mom`s teaching (proverbs 6:20-23) and thankful that she`s on twitter too! Love you ',
#   {'entities': [[26, 34, 'thankful']]}),
#  (' Thanks twilight... i know we love canon',
#   {'entities': [[1, 7, 'Thanks']]}),
#  (' Oh no!!  Hope you get better for your show in Argentina! Good luck!',
#   {'entities': [[1,
#      68,
#      'Oh no!!  Hope you get better for your show in Argentina! Good luck!']]}),
#  (' Good Luck.. mine 3rd day today !', {'entities': [[1, 11, 'Good Luck.']]}),
#  (' I will have spent my allowance at cybernet expo in SF by then  send me a dm with rates, tho, mayb cash flo bttr 4 me then',
#   {'entities': [[104, 114, 'flo bttr 4']]}),
#  ('_21Thanks, I`ll keep working on her    lol good idea!',
#   {'entities': [[0, 10, '_21Thanks,']]}),
#  ('am chillaxin after a busy BankHoliday, Hope everbody had a gd wkend! Holiday in 12 days!!!  ****',
#   {'entities': [[0,
#      89,
#      'am chillaxin after a busy BankHoliday, Hope everbody had a gd wkend! Holiday in 12 days!!']]}),
#  (' Hi Susan, read your blog.  It`s really good.  I look forward for the tweet updates',
#   {'entities': [[38, 44, 'y good']]}),
#  ('  #lichfield #tweetup sounds like fun  Hope to see you and everyone else there!',
#   {'entities': [[20, 37, 'p sounds like fun']]}),
#  (' hahah  okay then thanks for this short explanation ;)',
#   {'entities': [[16, 24, 'n thanks']]}),
#  ('contemplating borrowing one of my moms dogs just for today..i want to take care of someone.',
#   {'entities': [[70, 79, 'take care']]}),
#  (' Good luck on Monday!  Keep on rockin`', {'entities': [[1, 5, 'Good']]}),
#  ('i find John Mayer`s tweets mighty entertaining for a hearty laugh...so thanks John',
#   {'entities': [[27, 46, 'mighty entertaining']]}),
#  (' oh no not difficult. It`s just nuts that`s how you have to market yourselves on home turf',
#   {'entities': [[1, 21, 'oh no not difficult.']]}),
#  (' Ahhhh \\you are soo smart  Thanks for this schooling of thoughts  Have you taught before?',
#   {'entities': [[1, 25, 'Ahhhh \\you are soo smart']]}),
#  (' Thank you', {'entities': [[1, 10, 'Thank you']]}),
#  ('monday at the school  gosshhh what I`ve been waiting for',
#   {'entities': [[30, 56, 'what I`ve been waiting for']]}),
#  ('OMG I would sooooo make dis show number one n da ratings',
#   {'entities': [[0, 43, 'OMG I would sooooo make dis show number one']]}),
#  ("   Hey everyone! I just mixed the first single....!  'Why R U' ...I`m sooo excited!",
#   {'entities': [[63, 81, '...I`m sooo excite']]}),
#  (' thank you!', {'entities': [[1, 11, 'thank you!']]}),
#  ('  a good girl nevah tells hahahahaha! hope you had a good weekend',
#   {'entities': [[2, 8, 'a good']]}),
#  ('is planning her week, its going to good, going to get a lot of stuff done',
#   {'entities': [[35, 40, 'good,']]}),
#  ('_Efron 17 Again was amazing! I have seen it three times! It`s just hilarious, and you are fantastic!',
#   {'entities': [[10,
#      100,
#      'Again was amazing! I have seen it three times! It`s just hilarious, and you are fantastic!']]}),
#  (' thanks  and ill cross my fingers for you, that the rain will stop',
#   {'entities': [[1,
#      66,
#      'thanks  and ill cross my fingers for you, that the rain will stop']]}),
#  ('happy 1 year! <3', {'entities': [[0, 16, 'happy 1 year! <3']]}),
#  ('In bed now  tonight has been really really funny, best family ever !',
#   {'entities': [[43, 49, 'funny,']]}),
#  (' hes definitely my fav host ever!  Can`t wait to watch the rest tomorrow!!',
#   {'entities': [[16, 33, 'my fav host ever!']]}),
#  ('City Dippin iz u fun, so much eye candy out here...I remember y I miss  LOL',
#   {'entities': [[0,
#      75,
#      'City Dippin iz u fun, so much eye candy out here...I remember y I miss  LOL']]}),
#  ('Neville88 am gud enuh hun...was jus sayin hi n hopin that ur avin a gud nite so far..HAPPY LADIES DAY 2MORO THEN...is dat better',
#   {'entities': [[85, 90, 'HAPPY']]}),
#  ('My industrial is repierced, and I made a cute little friend',
#   {'entities': [[41, 45, 'cute']]}),
#  ('i forgot to put my work clothes in the dryer  also, i love my new slippers!',
#   {'entities': [[52, 75, 'i love my new slippers!']]}),
#  ('good morning everyone! hope you al have a lovely sunday!  (and i do hope it doesnt rain tomorrow :|)',
#   {'entities': [[23, 48, 'hope you al have a lovely']]}),
#  ('All you moms, get ready to enjoy your much-deserved special day!',
#   {'entities': [[0,
#      64,
#      'All you moms, get ready to enjoy your much-deserved special day!']]}),
#  ('ran over a worm skating...  poor wormie. but glad to be back.',
#   {'entities': [[45, 49, 'glad']]}),
#  ('I`m my mom`s company picnic at a Lake Elsinore Storm game. Oh the things we do to please moms',
#   {'entities': [[73, 93, 'we do to please moms']]}),
#  ('Cannot wait to get all dolled up and go out tonight',
#   {'entities': [[0, 11, 'Cannot wait']]}),
#  ('watching my baby on snl !  baby you look greaaaaat ;)',
#   {'entities': [[41, 50, 'greaaaaat']]}),
#  ('I think Destiny has officially gone crazy... hahahaha',
#   {'entities': [[45, 53, 'hahahaha']]}),
#  ("just watched that  new T-mobile advert on Youtube.. i love it  'hey jude!!!!!!'",
#   {'entities': [[54, 58, 'love']]}),
#  (' how fun!  where is the twitpic! I had purple hair once...',
#   {'entities': [[5, 9, 'fun!']]}),
#  ('http://bit.ly/PenQl  I`ve added a new icon to the feedicon database  Have some fun with it!',
#   {'entities': [[66, 91, 'e  Have some fun with it!']]}),
#  (' OMG, you have curly hair! Too cute!',
#   {'entities': [[27, 36, 'Too cute!']]}),
#  (' I was thinking that too this morning. Don`t worry it soon passes',
#   {'entities': [[39, 50, 'Don`t worry']]}),
#  (' i like the optimism', {'entities': [[3, 7, 'like']]}),
#  ('y do i only have 2 people following me  people follow me please x',
#   {'entities': [[57, 63, 'please']]}),
#  ('Had a good time at Flap-a-taco with , , and ',
#   {'entities': [[6, 10, 'good']]}),
#  (' Ugh, looks like you`ll have some work to do . Good luck',
#   {'entities': [[1,
#      56,
#      'Ugh, looks like you`ll have some work to do . Good luck']]}),
#  ('wish I could feel no pain (8)  but it`s ok, at least they like Brazil!',
#   {'entities': [[58, 62, 'like']]}),
#  ('my guys call me ``BartÂ\xa0ofÂ\xa0theÂ\xa0criticalÂ\xa0questions``. I`m guessing that`s a good thing.  #zeropoint.IT',
#   {'entities': [[78, 82, 'good']]}),
#  (' morning. hope its a good day despite the revising',
#   {'entities': [[21, 25, 'good']]}),
#  ('_Company Hey Kathy, happy Mother`s Day!',
#   {'entities': [[20, 25, 'happy']]}),
#  ('Plain White T`s and Sara Bareilles...can life get more amazing',
#   {'entities': [[55, 62, 'amazing']]}),
#  (' that sounds cool! post video!!',
#   {'entities': [[1, 18, 'that sounds cool!']]}),
#  ('  hope you guys are having fun!  Can`t wait for ya`ll to be back, Wilmy isn`t the same without you',
#   {'entities': [[25, 30, 'g fun']]}),
#  ('Awww I wonder when ima get married. Shawna and Damon are so cute',
#   {'entities': [[36, 64, 'Shawna and Damon are so cute']]}),
#  (' there coming this year ^-^  wiL said it himself  but yes now would be good.',
#   {'entities': [[51, 75, 'ut yes now would be good']]}),
#  (' omg in your pic youu look so cuute !',
#   {'entities': [[17, 37, 'youu look so cuute !']]}),
#  ('http://twitpic.com/4jeij - New forest hoping the walk would lose me some pounds',
#   {'entities': [[27,
#      79,
#      'New forest hoping the walk would lose me some pounds']]}),
#  (' Happy Birthday and cheers to PAO!!', {'entities': [[1, 6, 'Happy']]}),
#  ('star treeeeek?! only one hot guy there  and i get to watch him do his hot stuff woo.',
#   {'entities': [[80, 84, 'woo.']]}),
#  (' Awhhh age doesn`t matter, you awesome lady you!',
#   {'entities': [[27, 48, 'you awesome lady you!']]}),
#  ('Love the 3 mile 3AM runs. They make me smile',
#   {'entities': [[0, 7, 'Love th']]}),
#  ('  You are such a positive thinker, I am for sure keeping you around!',
#   {'entities': [[2, 33, 'You are such a positive thinker']]}),
#  (' ....nope.. its for the 1st time we invited her at SSM  and she very graceful accepted it !',
#   {'entities': [[58, 89, 'd she very graceful accepted it']]}),
#  (' true, depends on the couple  Personally we`ve found adding more has increased the fun & increased our bond',
#   {'entities': [[80, 86, 'he fun']]}),
#  (' diggin` your moustachio! Looking good daddio!',
#   {'entities': [[26, 46, 'Looking good daddio!']]}),
#  ('fireworks @ KBOOM concert... second best I`ve ever seen...preceded only by last year`s show 2008 <sigh>',
#   {'entities': [[29, 40, 'second best']]}),
#  (' dude... i tried the vegetarian thing and i lasted about 2 months... good luck!!! going vegan is intense!!! good move though.',
#   {'entities': [[69,
#      125,
#      'good luck!!! going vegan is intense!!! good move though.']]}),
#  (' Good morning to you. Hope you have a nice productive day',
#   {'entities': [[38, 57, 'nice productive day']]}),
#  ('lucky to be where i belong', {'entities': [[0, 5, 'lucky']]}),
#  ('Awesome beer pong party at my house in the yard tonight  going in when the sun is rising is officially B.A.',
#   {'entities': [[0, 7, 'Awesome']]}),
#  ('Kinda feeling in a reggae mood.... hope you all enjoy the smoothness on this lovely weekend',
#   {'entities': [[35,
#      91,
#      'hope you all enjoy the smoothness on this lovely weekend']]}),
#  ('speakerphone with the bestie  love that kid http://tinyurl.com/qxyc2n',
#   {'entities': [[22, 28, 'bestie']]}),
#  ('Happy mothers day mom.. i love yew...', {'entities': [[0, 5, 'Happy']]}),
#  ('**** it, the guys aren`t at #comet09  I hope they win though',
#   {'entities': [[40, 44, 'hope']]}),
#  ('My sister graduated today  it was amazing and super emotional. Wow ...',
#   {'entities': [[34, 41, 'amazing']]}),
#  (' http://twitpic.com/4jaz5 - Cool... luv it',
#   {'entities': [[36, 39, 'luv']]}),
#  ('wzzzzzzzzzup?! its derrek! we r just starting band practice. Jayk Skylar is leaving for california today. lucky.',
#   {'entities': [[106, 112, 'lucky.']]}),
#  (' glad u liked post  looking at the back end now...the sub 2 your blog is automatic. send url and i`ll verify.',
#   {'entities': [[1, 5, 'glad']]}),
#  ('i wanna good breakfast with   school is wiggity whack!',
#   {'entities': [[0, 22, 'i wanna good breakfast']]}),
#  ('_Neith James just doesn`t take a bad pic! Colossal loveliness! (wondering if I spelt colossal right...)',
#   {'entities': [[51,
#      103,
#      'loveliness! (wondering if I spelt colossal right...)']]}),
#  ('the last song all american rejects.......... an amazing song',
#   {'entities': [[45, 60, 'an amazing song']]}),
#  ('  Happy Mother`s Day to both of yall.  from me and my boys...',
#   {'entities': [[2, 7, 'Happy']]}),
#  ('All moved in to our new apartment. So exciting',
#   {'entities': [[35, 46, 'So exciting']]}),
#  ('i`m just sooo in love....i think',
#   {'entities': [[9, 23, 'sooo in love..']]}),
#  (' totally! I`ve been waitin for somethin new and thought provoking at mj.name',
#   {'entities': [[48, 65, 'thought provoking']]}),
#  (' yeah twitter is a lot of fun babe... especially when you`ve got ppl to talk to! lol & that sounds Goooooood lol',
#   {'entities': [[1,
#      112,
#      'yeah twitter is a lot of fun babe... especially when you`ve got ppl to talk to! lol & that sounds Goooooood lol']]}),
#  ("Congratulations to Manny 'Pacman' Pacquiao! You`ve made every Filipino proud of being a Filipino!",
#   {'entities': [[0, 15, 'Congratulations']]}),
#  (' lol i know but it was just so funny, ahaha',
#   {'entities': [[31, 37, 'funny,']]}),
#  ('_ omg and you never would believe what we did. ahaha, i loved it. but it felt like a movie, but REAL!!',
#   {'entities': [[56, 61, 'loved']]}),
#  (' http://twitpic.com/4w8ja - **** Felicia is freakin cute',
#   {'entities': [[28, 56, '**** Felicia is freakin cute']]}),
#  ('greeting again every momma : Happy Momma`s Day!',
#   {'entities': [[0, 47, 'greeting again every momma : Happy Momma`s Day!']]}),
#  ('Had the best wknd with her man and levi and sara love u guys',
#   {'entities': [[49, 53, 'love']]}),
#  ('Liking the Windows 7 Release Candidate so far... (also liking my new video card and terabyte harddisk  )',
#   {'entities': [[0, 6, 'Liking']]}),
#  (' i knooow  its the pizza girl episode xD <3',
#   {'entities': [[1, 43, 'i knooow  its the pizza girl episode xD <3']]}),
#  ('_d ...I`m so happy for you guys! COngratulations!',
#   {'entities': [[13, 18, 'happy']]}),
#  ('alright, rawknroll.net live on radio23.org - next 2 hours of vivid spring to summer music  rawk on and enjoy!',
#   {'entities': [[103, 109, 'enjoy!']]}),
#  (' nothing sweeter than YOUR 4-year-old!',
#   {'entities': [[1, 21, 'nothing sweeter than']]}),
#  (' LMAO. Joey is mine  I cant wait to meet them in july!',
#   {'entities': [[21, 45, 'I cant wait to meet them']]}),
#  ('Happy Mother`s Day 2 all the fabulous moms out there. The world wouldn`t run without us. Keep up the good work! Enjoy ur day',
#   {'entities': [[0, 5, 'Happy']]}),
#  ('Went shopping a lil... I deserve it... And now a night on the town in the big city of Norfolk',
#   {'entities': [[25, 32, 'deserve']]}),
#  ('Don`t follow your dreams; chase them.- Richard Dumb (who I think is very smart',
#   {'entities': [[53, 78, 'who I think is very smart']]}),
#  (' Ha! Thanks Bryan! And don`t remind me about the state budget issues.  Actually, Steve only has 6 staffers in 3 offices.',
#   {'entities': [[5, 11, 'Thanks']]}),
#  (' Will we see you guys in the Philippines?  That would be the coolest thing ever! Always wanted to go to one of your concerts!',
#   {'entities': [[43, 80, 'That would be the coolest thing ever!']]}),
#  ('_Jane14 okay well then now i don`t feel so bad lmao',
#   {'entities': [[29, 46, 'don`t feel so bad']]}),
#  (' Journey!? Wow... u just became cooler.  hehe... (is that possible!?)',
#   {'entities': [[11, 39, 'Wow... u just became cooler.']]}),
#  ('This is Really Cool put in a topic and its a twitter show...If your a tweeter twittering twit u got to luv this http://bit.ly/a0nw',
#   {'entities': [[15, 19, 'Cool']]}),
#  ('So tired and I have to work till 10:30 tonight!    Happy mothers day to everyone too  http://tinyurl.com/qu62bl',
#   {'entities': [[51, 79, 'Happy mothers day to everyon']]}),
#  ('Going to bed. Talk to ya later!  goodnight birdies LOL',
#   {'entities': [[33, 54, 'goodnight birdies LOL']]}),
#  ('_D_ happy birthday', {'entities': [[0, 18, '_D_ happy birthday']]}),
#  ('HAPPY MOTHERS DAY TO ALL THE MOMS OUT THERE !!!',
#   {'entities': [[0, 5, 'HAPPY']]}),
#  ('_tennant yes! Watching season 2 all evening.  Wish I could get BBC2',
#   {'entities': [[46, 50, 'Wish']]}),
#  ('i want so bad to go to the mcfly`s concert  anybody up to go with me?',
#   {'entities': [[0, 9, 'i want so']]}),
#  ('going to see star trek with my babe  im actually excited about this hah',
#   {'entities': [[49, 56, 'excited']]}),
#  ('happy mother`s day! I love you mama',
#   {'entities': [[20, 35, 'I love you mama']]}),
#  (' Since you travel quite often and use online travel sites we would love some feedback on iXiGO.com from you',
#   {'entities': [[67, 71, 'love']]}),
#  (' Awww... It works ok for me.. but I have an apple laptop so it might be a little difference!!',
#   {'entities': [[9, 20, 'It works ok']]}),
#  ('  thanks!', {'entities': [[2, 8, 'thanks']]}),
#  ('Joan is such a legend! I can`t wait for apprentice finale!!! im so addicted i think i need a rehab!! LOL tweet later..  xoxo',
#   {'entities': [[15, 24, 'legend! I']]}),
#  ("_om 'If I should paint my fingernails green- oh and it just so happens I do paint them green...'  Marvelous",
#   {'entities': [[98, 107, 'Marvelous']]}),
#  ('Happy Mother`s Day to all the Ladies... With all the moments we cherish with our children, today let those moments cherish you in return.',
#   {'entities': [[0, 5, 'Happy']]}),
#  ("'I`ll see you again yeah?' 'Its up to you' 'I guarantee you will, i dont want to wait to long not seeing you' **** fruit basket! Hahaha",
#   {'entities': [[129, 135, 'Hahaha']]}),
#  ("Demoing with Gary burr!!! So excited to get some 'girls' music on tape!! Missing Tayla",
#   {'entities': [[29, 36, 'excited']]}),
#  (' excuse me ...theres me!!!  jkidding lol...so how long b4 yr fun night out starts lol',
#   {'entities': [[59, 64, 'r fun']]}),
#  ('Sending love & respect to all the mommies out in the twitterverse! You all inspire me!!',
#   {'entities': [[8, 12, 'love']]}),
#  ('watered the tomato plants, pepper plants and lettuce, feeling all homely! off out with Freddie for a fun-packed day',
#   {'entities': [[54,
#      115,
#      'feeling all homely! off out with Freddie for a fun-packed day']]}),
#  ('First Happy Mothers Day  Second what is it that makes us think the way we do? Why do we feel the way we feel? I dont know but i wish i did',
#   {'entities': [[6, 11, 'Happy']]}),
#  ('Sooo, I spent most of my day sitting at home in front of the computer in my pajamas...I love these days.',
#   {'entities': [[88, 92, 'love']]}),
#  ('Finally home  Gonna hit the hay n sleep till noon lol',
#   {'entities': [[0, 7, 'Finally']]}),
#  ('Happy Mother`s Day to all the moms! If you`re an awesome mom, you`ll help #savechuck',
#   {'entities': [[0,
#      84,
#      'Happy Mother`s Day to all the moms! If you`re an awesome mom, you`ll help #savechuck']]}),
#  (' Yes, we will! We should maybe do it in a DM though so we don`t annoy our followers. Thought of that too late.    Good night!',
#   {'entities': [[52,
#      123,
#      'so we don`t annoy our followers. Thought of that too late.    Good nigh']]}),
#  ('Happy mother`s day everyone! still playing pet society!',
#   {'entities': [[0, 5, 'Happy']]}),
#  (' i looooove me some star trek. runs in the family',
#   {'entities': [[3, 11, 'looooove']]}),
#  ('http://twitpic.com/4wt8a - pretty **** good friday night',
#   {'entities': [[39, 43, 'good']]}),
#  ('I Love You MOM....alwayyyyyyyssssssss', {'entities': [[2, 6, 'Love']]}),
#  (' Smile. Everything worked out.',
#   {'entities': [[1, 30, 'Smile. Everything worked out.']]}),
#  (': Lol it went okay! As far as I can tell . But then I had to do a test today for geo and I was all zoned out and got like 65%',
#   {'entities': [[2, 22, 'Lol it went okay! As']]}),
#  (' haha Good job getting close. Her eyes are set somewhere else though',
#   {'entities': [[4, 14, 'a Good job']]}),
#  ('Man, looking through and packing up my books is looking at my past lives. Feeling kind of sentimental',
#   {'entities': [[74, 101, 'Feeling kind of sentimental']]}),
#  ('Currently in costa coffee  im liking this place more and more. Were sat in the business lounge. ooo were businessy today.',
#   {'entities': [[27, 62, 'im liking this place more and more.']]}),
#  (' Hope you find a nice and healthy, also cheap, breakfast!',
#   {'entities': [[17, 21, 'nice']]}),
#  (' **** straight you know what the game is, and if you`ve heard the tracks you`ll know why I`ve been rocking out',
#   {'entities': [[1,
#      110,
#      '**** straight you know what the game is, and if you`ve heard the tracks you`ll know why I`ve been rocking out']]}),
#  ('i love this girl  ,she rocks!',
#   {'entities': [[0, 29, 'i love this girl  ,she rocks!']]}),
#  ('_30439 I really wish I could go!', {'entities': [[16, 20, 'wish']]}),
#  (' Baking WIN! Thanks for that!', {'entities': [[13, 19, 'Thanks']]}),
#  ('Toris was SO fun! JB MOVIE WAS ABSOLUTELY AMAZING! and i had a good day at work!  YAY i loved the movie! :0',
#   {'entities': [[31,
#      107,
#      'ABSOLUTELY AMAZING! and i had a good day at work!  YAY i loved the movie! :0']]}),
#  (' What Makes Me Happy? My Daughter, My Family & Their Support, Money, Shopping, & Restaurants',
#   {'entities': [[15, 21, 'Happy?']]}),
#  ('is excited for tonight`s party of ron  http://plurk.com/p/sujth',
#   {'entities': [[3, 10, 'excited']]}),
#  ('Looking to sketch final catwalk outfit, i really REALLY want my long pink hair back. i also want to dye my models hair pink not allowed',
#   {'entities': [[40, 84, 'i really REALLY want my long pink hair back.']]}),
#  (' What is everyone saying about the supposed **** pics of Matt Striker? Hope he doesn``t get in trouble',
#   {'entities': [[71, 102, 'Hope he doesn``t get in trouble']]}),
#  ('Dad`s retelling his saskatoon m&g story, love hearing what the guys said to him  I never heard any of it',
#   {'entities': [[41, 45, 'love']]}),
#  ('Thanks to all my new followers!', {'entities': [[0, 6, 'Thanks']]}),
#  ('hoping to hear from you all soon',
#   {'entities': [[0, 32, 'hoping to hear from you all soon']]}),
#  (' sounds good.  and yeah, I turn 21 tomorrow so I`ll definitely be partying.',
#   {'entities': [[1, 13, 'sounds good.']]}),
#  (" thank you  btw, if u`re wondering, you can check out the 'Fuel' brand here (  )",
#   {'entities': [[1, 10, 'thank you']]}),
#  (' LOL! No trialing...for the most part Florida trials come to a screeching halt over the summer.  Have fun this weekend!',
#   {'entities': [[100, 105, 'e fun']]}),
#  (' pretty much, thanks.  seeing if a little Gilbert & Sullivan will cheer me up more.',
#   {'entities': [[1,
#      83,
#      'pretty much, thanks.  seeing if a little Gilbert & Sullivan will cheer me up more.']]}),
#  (' i know ridiculous! we never got to hang out  i love chicago and want to go shopping... so a trip sounds like fun',
#   {'entities': [[86, 113, '. so a trip sounds like fun']]}),
#  ('Hellerrr new followerss. I`m Tricina & uhhm I`m cool',
#   {'entities': [[48, 52, 'cool']]}),
#  (' i wish you still loved me',
#   {'entities': [[1, 26, 'i wish you still loved me']]}),
#  ('errbody, please check out http://mscaseycarter.blogspot.com. id appreciate it a bunch.',
#   {'entities': [[64, 74, 'appreciate']]}),
#  (' i hope that happens tomorrow, then ill be there ;) (Providing my dad gets better to take me  )',
#   {'entities': [[3, 7, 'hope']]}),
#  ('Good Morning!  ? http://blip.fm/~5jnl7',
#   {'entities': [[0, 13, 'Good Morning!']]}),
#  (' http://twitpic.com/4hbs5 - ahahahahahahahaha can i please eat that off your head  ****',
#   {'entities': [[28, 45, 'ahahahahahahahaha']]}),
#  (' AWESOME! It feels very fulfilling, doesn`****?  I`m gonna work on SOOOO many people over the summer! Totally excited!',
#   {'entities': [[1, 9, 'AWESOME!']]}),
#  ('http://twitpic.com/67wb4 - Gotta a show on Monday at 9.... hopefully my head will be better by then....',
#   {'entities': [[59, 71, 'hopefully my']]}),
#  ('Last day to sign up for GoCincinnati! www.crossroads.net/gocincinnati you can sign up with my group.. its going to be AWESOME',
#   {'entities': [[118, 125, 'AWESOME']]}),
#  ('hi  thanks for the follow  good luck with your friend? ha',
#   {'entities': [[27, 36, 'good luck']]}),
#  ('whew. did some more vacuuming. what a good time! You should vacuum.',
#   {'entities': [[38, 42, 'good']]}),
#  ('yo yo yo! i like ice cream',
#   {'entities': [[0, 26, 'yo yo yo! i like ice cream']]}),
#  ('What an incredibly great day.  hahaha!',
#   {'entities': [[5, 38, 'an incredibly great day.  hahaha!']]}),
#  (' congratulations, you two are so well suited   have a lovely day x',
#   {'entities': [[1, 17, 'congratulations,']]}),
#  (' oh my gosh, loved it!', {'entities': [[13, 22, 'loved it!']]}),
#  (' OMG! It`s the famous Amanda woman person thingy!  HUGS ALL AROUND!',
#   {'entities': [[1,
#      67,
#      'OMG! It`s the famous Amanda woman person thingy!  HUGS ALL AROUND!']]}),
#  ('Got moommy somn special for mothers day',
#   {'entities': [[16, 23, 'special']]}),
#  ('is in class, trying to listen but I really like twitter, facebook, .& myspace  oh yeaaah .& I`m hungry!',
#   {'entities': [[34, 50, 'I really like tw']]}),
#  (' Thanks so much Jon.....same to your mom    That is so sweet of you to think of all of us',
#   {'entities': [[1, 7, 'Thanks']]}),
#  ('I wish Joe Bidden was on the train with me.',
#   {'entities': [[0, 6, 'I wish']]}),
#  (' You`re welcome...', {'entities': [[1, 16, 'You`re welcome.']]}),
#  ('im very much excited to go back to school',
#   {'entities': [[13, 20, 'excited']]}),
#  ('Listening to The Man Who Cant Be Moved <3 I just love the connection with GW  Doing Dutch and might do some art later.',
#   {'entities': [[42,
#      118,
#      'I just love the connection with GW  Doing Dutch and might do some art later.']]}),
#  ('To all mothers in the world : happy mothers day',
#   {'entities': [[30, 35, 'happy']]}),
#  (' Thanks mate, just came on board here at Twitter ...  .. tweet up sounds great..',
#   {'entities': [[64, 79, 'p sounds great.']]}),
#  ('well no phone today, we are waiting till June 9th to get a better deal sooooo  but its all good',
#   {'entities': [[91, 95, 'good']]}),
#  ('The top 5 words I`ve tweeted: hug, good, people, fun, twitter. http://tinyurl.com/dcxoty ... that`s really quite nice',
#   {'entities': [[93, 117, 'that`s really quite nice']]}),
#  ('going to a garden centre today. should be funn :/ currently drinking egyptian spice tea and watching hollyoaks',
#   {'entities': [[42, 46, 'funn']]}),
#  ('happy happy joy joy    is that good enough for you',
#   {'entities': [[0, 5, 'happy']]}),
#  (' haha what`s up Matt ?', {'entities': [[1, 5, 'haha']]}),
#  (' Awww!!', {'entities': [[1, 7, 'Awww!!']]}),
#  (' jip i have a good one', {'entities': [[5, 22, 'i have a good one']]}),
#  ('Today celebrating two new people becoming australian citizens. I am hoping for a good dinner.',
#   {'entities': [[81, 85, 'good']]}),
#  ('Is at the botanical gardens and its beautiful but she forgot an extra memory card so no pictures today',
#   {'entities': [[32, 45, 'its beautiful']]}),
#  (' i already got my tickets to your concert here in the philippines! im so excited!',
#   {'entities': [[73, 81, 'excited!']]}),
#  (' Congratulations! Check that one off your to do list!',
#   {'entities': [[1, 17, 'Congratulations!']]}),
#  (' thank YOU!! You guys did awesome things for my blog tonight  so grateful!!',
#   {'entities': [[62, 75, 'so grateful!!']]}),
#  ('unpacking my new toy arrived in the studio right now  it`s called TC Finalizer. can`t wait to check how it sounds !!!',
#   {'entities': [[80, 90, 'can`t wait']]}),
#  (' omfg I have been DOWNING them they are so tasty. I ate almost all of them with Lo',
#   {'entities': [[43, 49, 'tasty.']]}),
#  ('Our kids are both in a Derbyshire schools string concert at the Buxton Opera House today. They`re both quite excited',
#   {'entities': [[109, 116, 'excited']]}),
#  ('Such a fun night. I needed the break. PS- I love you man is effing hilarious! Good night twitter world. Sweet dreams',
#   {'entities': [[7, 10, 'fun']]}),
#  ('woo hoo its friday!! ....wait.... i have to work at the cleaners tomorrow.',
#   {'entities': [[0, 10, 'woo hoo it']]}),
#  (' Yay! I too had some joy in that department',
#   {'entities': [[19, 24, 'e joy']]}),
#  (' Wooops! Meant I agree with Boomstone..trying 2 reply 2 both, LOL. Happy Mothers Day to you as well!  TTY soon!',
#   {'entities': [[59, 100, 'h, LOL. Happy Mothers Day to you as well!']]}),
#  (' LOL we`re such twitter addicts',
#   {'entities': [[1, 31, 'LOL we`re such twitter addicts']]}),
#  ('Gonna celebrate Mothers Day with the family but gonna start the partying tonite',
#   {'entities': [[64, 72, 'partying']]}),
#  (' we can`t wait to see you too! pls come back to iowa it isn`t the same at the theatre',
#   {'entities': [[1, 25, 'we can`t wait to see you']]}),
#  ('Feeling good about our win! Its nice being softball champs  bring on the season!',
#   {'entities': [[0,
#      80,
#      'Feeling good about our win! Its nice being softball champs  bring on the season!']]}),
#  ('havent been on here in ages  sorry twitter.. tweetdeck is broken',
#   {'entities': [[29, 34, 'sorry']]}),
#  (' Thanks for the tip on otherinbox...  It won`t work with outlook for me...',
#   {'entities': [[1, 7, 'Thanks']]}),
#  ('Greg back in the top 10. This is why I love Nascar.',
#   {'entities': [[39, 43, 'love']]}),
#  ('had cold rock, choc mint+bubblegum+cookie+flake+nerds= YUM!!!! XD .  had a fun day.',
#   {'entities': [[75, 78, 'fun']]}),
#  (' LOL yeah  I forgot about your TweetDeck statuses! So funny',
#   {'entities': [[52, 59, 'o funny']]}),
#  ('Everyone`s talking about the goodies at #BEA09.  I wanna be there.',
#   {'entities': [[49, 66, 'I wanna be there.']]}),
#  ('Very succesful Cancertown Launch yesterday',
#   {'entities': [[0, 14, 'Very succesful']]}),
#  ('Photo: Great night.  http://tumblr.com/xmo1pgymj',
#   {'entities': [[7, 12, 'Great']]}),
#  ('Cool. Cant wait for dustbin baby', {'entities': [[0, 5, 'Cool.']]}),
#  ('with harry.. baked. love you cassie.. BUT YOU`RE NOT ONLINE!?',
#   {'entities': [[20, 37, 'love you cassie..']]}),
#  (' LOL!  Too true', {'entities': [[1, 15, 'LOL!  Too true']]}),
#  (' Florida should be nice.', {'entities': [[19, 24, 'nice.']]}),
#  ('Happy Mother`s Day to all the mothers out there! Goodnight to everyone else',
#   {'entities': [[0, 5, 'Happy']]}),
#  ('okay, need to hit the sack.  i gotta wake up in like 5 hours   goodnight everyone!',
#   {'entities': [[63, 81, 'goodnight everyone']]}),
#  ('  let`s hope so', {'entities': [[2, 15, 'let`s hope so']]}),
#  (' good luck!!  OH and I are playing inthe mixed knockout this week. Playing the pros 14yr old son playing off 5 & top woman off 6',
#   {'entities': [[1, 12, 'good luck!!']]}),
#  (' http://twitpic.com/4jjlc - I love it! If it`s pouring rain, I still want to go.',
#   {'entities': [[30, 34, 'love']]}),
#  (' i know, right? i`m super-excited - i told y`all this is the busiest time of year for me',
#   {'entities': [[20, 33, 'super-excited']]}),
#  (' i`ve heard that ST isn`t true imax- shot at 1828x1556 and blown up to 4096, still- nice big screen!',
#   {'entities': [[84, 100, 'nice big screen!']]}),
#  (' She could spend the rest of the night in her room.  At least ONE of you could be happy with a glass of wine.    #surlytween',
#   {'entities': [[53,
#      108,
#      'At least ONE of you could be happy with a glass of wine']]}),
#  ('The horoscopes website I use has all changed around  I like it!',
#   {'entities': [[55, 59, 'like']]}),
#  ('Great meeting...lunch on the patio in the sunshine...nothing more perfect  busy day...time for bed, ahhhhh',
#   {'entities': [[0, 15, 'Great meeting..']]}),
#  ('_ranjan Did I ever mention what a nice and awesome dude you are?',
#   {'entities': [[43, 50, 'awesome']]}),
#  ('just had a bbq... YUM im full now',
#   {'entities': [[18, 33, 'YUM im full now']]}),
#  ('Moveout should be fun. Thank you VT students for working to make VT the best that it can possibly be',
#   {'entities': [[18, 22, 'fun.']]}),
#  ('Aww, I love my daddy! He works 7 days a week almost all day and still tries to go to SF with all of us',
#   {'entities': [[5, 14, 'I love my']]}),
#  ('_shantz heyy shantell!  twitter is cool, thats why! and guess what!! i followed britney spears, and she followed me back!',
#   {'entities': [[35, 40, 'cool,']]}),
#  (' http://twitpic.com/336u5 - i love her too !!! she shouldve won',
#   {'entities': [[28, 63, 'i love her too !!! she shouldve won']]}),
#  (' ima goodgirl I`m not down with takin advantage',
#   {'entities': [[5, 13, 'goodgirl']]}),
#  ('in rye..happy mothers day mums  ily mummy  lol',
#   {'entities': [[8, 13, 'happy']]}),
#  (' yippee, darling girls. Love you sooooo much  and so thrilled you found each other!',
#   {'entities': [[51, 61, 'o thrilled']]}),
#  (' I sorry', {'entities': [[1, 8, 'I sorry']]}),
#  ('wishes all you moms a happy & blessed Mother`s Day!',
#   {'entities': [[0,
#      51,
#      'wishes all you moms a happy & blessed Mother`s Day!']]}),
#  ('alright, back from my twitter decompression  Happy monday folks, what`s the good word?',
#   {'entities': [[45, 64, 'Happy monday folks,']]}),
#  ('White House joins social networking sites > http://bit.ly/15Fo4X - better late than never',
#   {'entities': [[67, 89, 'better late than never']]}),
#  (' now that you say that you do look like demi  hahaha!! Yessss august 2nd will be a blast',
#   {'entities': [[60, 88, 's august 2nd will be a blast']]}),
#  (' Sweeny Todd is an awesome movie, the best',
#   {'entities': [[17, 26, 'n awesome']]}),
#  ('  Yeah I`m okay been icing and ace bandage and sitting on my **** on twitter... LOL Thanks',
#   {'entities': [[76, 88, '... LOL Than']]}),
#  (' I am blessed beyond measure', {'entities': [[6, 13, 'blessed']]}),
#  ('is chilling at home', {'entities': [[0, 19, 'is chilling at home']]}),
#  (' Oh, that would be riveting TV!   Trips to the break room, coffee, toothpicks in the eyes to keep them open.',
#   {'entities': [[17, 27, 'e riveting']]}),
#  ('Getting one of our field vehicles cleaned. Looks like our action hero governor wants to give me another furlough day. How nice of him',
#   {'entities': [[122, 126, 'nice']]}),
#  ('wants to greet all the mom`s out there a Happy Mothers Day!!! May you enjoy your day!!',
#   {'entities': [[41, 46, 'Happy']]}),
#  (' Thanks Anita, I am looking for hosting, I will look at them too',
#   {'entities': [[1, 14, 'Thanks Anita,']]}),
#  ('made breakfast today......Happy mother`s day ..',
#   {'entities': [[26, 31, 'Happy']]}),
#  (' Yep. I hope my lame attempt with the spaces helped me to hinder them, lol. I know tomorrow I guess.',
#   {'entities': [[45, 51, 'helped']]}),
#  (' He`s a good lad is wore Phil...  known each other for 22 years now... seems like 5 minutes!!  haha   You ok Hayley?',
#   {'entities': [[1, 16, 'He`s a good lad']]}),
#  (' ur welcome sweetie . Anytime . I need to find a way to get more followers , I don`t have many',
#   {'entities': [[1, 19, 'ur welcome sweetie']]}),
#  (' ...Now I`m going back to bed. LOL. Enjoy your time at the gym. I`ll be sleeping.',
#   {'entities': [[36, 41, 'Enjoy']]}),
#  (' haha that`s way cool! Good morning',
#   {'entities': [[1, 22, 'haha that`s way cool!']]}),
#  ('life`s good', {'entities': [[7, 11, 'good']]}),
#  (' I love it. Tell me it didn`t match my shirt perfectly. Can you just not move PLEASE? What am I supposed to do without you?',
#   {'entities': [[3, 7, 'love']]}),
#  (' uhh, congrats for your two years anniversary',
#   {'entities': [[6, 14, 'congrats']]}),
#  (" aaaw... that`s very sweet of him. my girl friends gots to drag them hubbies just so we can 'nite-out'. unless my beer. LoL",
#   {'entities': [[9, 34, 'that`s very sweet of him.']]}),
#  (' That is the sweetest loveliest thing for you to say. You made me smile. Thank you for that.',
#   {'entities': [[1,
#      92,
#      'That is the sweetest loveliest thing for you to say. You made me smile. Thank you for that.']]}),
#  ('I do amazing at beer pong with my brother',
#   {'entities': [[0, 15, 'I do amazing at']]}),
#  (' Cool show last night had me in fits',
#   {'entities': [[1, 10, 'Cool show']]}),
#  (' Hahahahahahahahahah! That tickled me so much!',
#   {'entities': [[1, 21, 'Hahahahahahahahahah!']]}),
#  (' bahahaha. I love Gabriel - absolutely **** hilarious!!!',
#   {'entities': [[13, 17, 'love']]}),
#  (' omg yes!!!!!!! but I have to get ready for work early tonight  I have payroll distribution duty',
#   {'entities': [[1, 15, 'omg yes!!!!!!!']]}),
#  (' Good luck 2 u and the babies',
#   {'entities': [[1, 29, 'Good luck 2 u and the babies']]}),
#  ('_ that is the truth.', {'entities': [[0, 20, '_ that is the truth.']]}),
#  ('I hope I`m doing something right. Had an influx of reviews on a 1 year old fan fic telling me they love my style of writing for HP.',
#   {'entities': [[94, 131, 'they love my style of writing for HP.']]}),
#  (' thanks for the follow! Isafailure was supposed 2 b a team thing, but my friend hasn`t emailed me or communicated n 4ever',
#   {'entities': [[1, 23, 'thanks for the follow!']]}),
#  (' thats great babe!! congrats!!',
#   {'entities': [[1, 30, 'thats great babe!! congrats!!']]}),
#  ('I hope everyone had a great weekend! I will be here on and off today as I have 2 important meetings today',
#   {'entities': [[2, 6, 'hope']]}),
#  ('_creek No worries - thank google! There`s nothing you can`t find on there!',
#   {'entities': [[7, 33, 'No worries - thank google!']]}),
#  ('good morning to everyone',
#   {'entities': [[0, 24, 'good morning to everyone']]}),
#  (' see u bye see u!  i love the hot30', {'entities': [[19, 25, 'i love']]}),
#  ('Gorgeous day! Off to Hash around Waterley Bottom - wonderful name for a village! Quiz Mistressing at the Porto this evening',
#   {'entities': [[51, 65, 'wonderful name']]}),
#  ('That poor girl on britains got talent, god love her  forgot the words and cried  but gets a second chance to perform again : ]',
#   {'entities': [[83, 122, 't gets a second chance to perform again']]}),
#  (' happy birthday!', {'entities': [[1, 16, 'happy birthday!']]}),
#  (' mon ami since 5 years young  I loveeee her. Foreverrr',
#   {'entities': [[30, 54, 'I loveeee her. Foreverrr']]}),
#  ('Pool, alcohol, & a cute band, couldn`t ask for more on a Saturday night  #fb http://twitpic.com/4w1rr',
#   {'entities': [[0,
#      71,
#      'Pool, alcohol, & a cute band, couldn`t ask for more on a Saturday night']]}),
#  ('Hope all the Mum`s out there had a Mother`s Day with love, close family & friends.',
#   {'entities': [[53, 58, 'love,']]}),
#  ('Just got my heart ripped out  i love you guys',
#   {'entities': [[0, 45, 'Just got my heart ripped out  i love you guys']]}),
#  ('Rice is ready to eat.Off now to watch Comet 2009!The most important music price in germany.Wow n Lisa arrives around 12p.m.  Still 2 hours',
#   {'entities': [[91, 96, 'Wow n']]}),
#  ('Thank you, Afrin Nasal Spray! Also, I got a giant teacup tonight!',
#   {'entities': [[0, 10, 'Thank you,']]}),
#  ('Good morning', {'entities': [[0, 12, 'Good morning']]}),
#  (' Goooood Luck!', {'entities': [[1, 8, 'Goooood']]}),
# ...
#  (' nigel really enjoyed it, but he`s got a big scratch on his side that inexplicably appeared afterwards...',
#   {'entities': [[14, 21, 'enjoyed']]}),
#  ('its nice to have no assignments for the night',
#   {'entities': [[4, 8, 'nice']]}),
#  ('Good morning World! Happy Star Wars Day! May the 4th be with you!',
#   {'entities': [[0, 4, 'Good']]}),
#  (' Awwh....well at least you are up top, where the magic happens!  Today will be a good day, no worries.',
#   {'entities': [[79, 85, 'a good']]}),
#  ('3 years in 2 months!! hooorah! can`t wait!',
#   {'entities': [[31, 42, 'can`t wait!']]}),
#  (' WOw, that`s a lot of work.  I hope today is a day off for you.    I`m working as usual.  But, getting some playtime in too.',
#   {'entities': [[29, 35, 'I hope']]}),
#  (' Hi I have uploaded 5 completely new Chinese Lessons on www.youtube.com/ChineseLearn Please feel free to watch and enjoy',
#   {'entities': [[85, 120, 'Please feel free to watch and enjoy']]}),
#  ('() Oh snap... kinda nuts right now... :  I`ve told at least 27  Thanks babes.',
#   {'entities': [[64, 77, 'Thanks babes.']]}),
#  ('finally over my sickness.',
#   {'entities': [[0, 25, 'finally over my sickness.']]}),
#  ('45Th st pub anyone tonight? Dont want to be a lonely drunk tonight',
#   {'entities': [[28, 66, 'Dont want to be a lonely drunk tonight']]}),
#  ('I am excited to be home  finally a week and a weekend with people i know',
#   {'entities': [[5, 12, 'excited']]}),
#  (' too kind Jim too kind brother', {'entities': [[5, 9, 'kind']]}),
#  ('USA/Texas Jaycees Debate team ROCKED the house! They now have the opportunity to represent us in Tunsia, Africa! GO JAYCEES!',
#   {'entities': [[30, 36, 'ROCKED']]}),
#  ('Hey  Bye Bye  was fun too   (robluketic live > http://ustre.am/2w5v)',
#   {'entities': [[16, 21, 's fun']]}),
#  (' you`re welcome char, glad you liked the cake, it`s pretty simple you should give it a try',
#   {'entities': [[8, 15, 'welcome']]}),
#  ('Headache is gone,thank god!Time for tea i think',
#   {'entities': [[0, 47, 'Headache is gone,thank god!Time for tea i think']]}),
#  (' YAY! Hope your day at work is wonderful, Sis! We have a Bank Holiday in England today so everyone is off work',
#   {'entities': [[31, 41, 'wonderful,']]}),
#  ('I am listening to the music of Super Juniors of Korea. I so like the way they sing and dance. I hope someday i can meet them.',
#   {'entities': [[55, 64, 'I so like']]}),
#  ('i looked all cute too!', {'entities': [[13, 17, 'cute']]}),
#  (' congrats! You`re the first person i`ve heard/read say that today',
#   {'entities': [[1, 10, 'congrats!']]}),
#  (' FOR REAL!  Isn`**** exciting!!!!',
#   {'entities': [[12, 29, 'Isn`**** exciting']]}),
#  ('Is relaxing in bed for a while before I go to sleep. It was nice to get out of my house for a while tonight',
#   {'entities': [[60, 64, 'nice']]}),
#  ('Home. Should be in the bed, but I`m just super duper excited about tomorrow.',
#   {'entities': [[41, 60, 'super duper excited']]}),
#  ('Go Canada they made Nikkie Payne #1 comic well she is soo yeah but she is only funny to pervs or teens or people in my family',
#   {'entities': [[0,
#      125,
#      'Go Canada they made Nikkie Payne #1 comic well she is soo yeah but she is only funny to pervs or teens or people in my family']]}),
#  (' congratulations', {'entities': [[1, 16, 'congratulations']]}),
#  (' I know you would be successful. And you`re just starting. You would do great in the coming years. Good luck to you',
#   {'entities': [[21, 32, 'successful.']]}),
#  ('may,1st success for lucas first police contact after neighborhood cruising with eggs, cream, bumf, shaving foam. love my son he`s a hero',
#   {'entities': [[113, 136, 'love my son he`s a hero']]}),
#  ('just bought 5 bouquets of flowers and put em all together and arranged them all pretty for my momma in the morning!  ::proud of myself::',
#   {'entities': [[0,
#      136,
#      'just bought 5 bouquets of flowers and put em all together and arranged them all pretty for my momma in the morning!  ::proud of myself::']]}),
#  (' did you get them from california vintage? ahahah they have the BEST dresses, i want them but i dont have ebay',
#   {'entities': [[64, 68, 'BEST']]}),
#  ('Inspection went fine ... they like the house woopee. Would just be nice if it had been this morning so I could have done stuffs today',
#   {'entities': [[16, 20, 'fine']]}),
#  ('good afternoon.  http://plurk.com/p/suyev',
#   {'entities': [[0, 15, 'good afternoon.']]}),
#  ('Thank you all once more for all your lovely birthday messages',
#   {'entities': [[0, 5, 'Thank']]}),
#  (' hey chocolate chips is good.  i want a snack too but i`m out of snacks.',
#   {'entities': [[24, 29, 'good.']]}),
#  ('is having a well-deserved break today..NO PHONE CALLS, NO EMAILS..only plenty of catch up movies to doooooo',
#   {'entities': [[12, 31, 'well-deserved break']]}),
#  ('Happy Star Wars Day! May the 4th be with you!  http://tr.im/kq95',
#   {'entities': [[0, 5, 'Happy']]}),
#  ('The NVIDIA ION-based Lenovo IdeaPad S12 (  http://is.gd/J6Zy ) is awesome.  Fn key to left of Ctrl makes it non-starter for me though',
#   {'entities': [[66, 74, 'awesome.']]}),
#  ('just made a South-Korean email pal. Happy!',
#   {'entities': [[36, 42, 'Happy!']]}),
#  (' You too!   Happy Mom`s get to rule and kids have to take it day',
#   {'entities': [[12, 34, 'Happy Mom`s get to rul']]}),
#  ('Great weekend, even though my site is not moved. Plenty other things to do and learn. Keeping the faith and looking to the future',
#   {'entities': [[0, 5, 'Great']]}),
#  ('says i got 2 cards today, from eva n clara. thanks, guys.  http://plurk.com/p/roo6c',
#   {'entities': [[44, 51, 'thanks,']]}),
#  ('so I just had a violent fightclub like **** dream involving heavily tattooed ladies. I didn`t wanna wake up.  lol.',
#   {'entities': [[85, 114, 'I didn`t wanna wake up.  lol.']]}),
#  (' Haha of course! That`s my favorite album of all time',
#   {'entities': [[27, 53, 'favorite album of all time']]}),
#  ('Pappadeux has some yummy strawberry lemonade',
#   {'entities': [[19, 44, 'yummy strawberry lemonade']]}),
#  (' I was hoping I could just drop them into ~/.vim so both Vim and MacVim could share them',
#   {'entities': [[7, 13, 'hoping']]}),
#  ('just made a cake for mi madre  i`m goooooddd!',
#   {'entities': [[31, 45, 'i`m goooooddd!']]}),
#  (' good luck with it..Do well!! My best wishes are with you!',
#   {'entities': [[1, 5, 'good']]}),
#  ('wikileaks geht wieder  super #wikileaks #online',
#   {'entities': [[23, 28, 'super']]}),
#  ('The mothers day classic went really well, despite the cold 5.30am start',
#   {'entities': [[29, 41, 'really well,']]}),
#  ('Sitting at work, waiting for this day to be over with. It is always Fridays that take forever. Wish the weekend would get here already.',
#   {'entities': [[95, 99, 'Wish']]}),
#  ('Eating some ice cream cake  its bomb!', {'entities': [[32, 37, 'bomb!']]}),
#  ('had a great weekend in Stuttgart at the befah-conference. Wonderful people, nice discussions and lots of fun. Together we`re strong!',
#   {'entities': [[58, 67, 'Wonderful']]}),
#  (' Yay! Tell her I said congrats', {'entities': [[22, 30, 'congrats']]}),
#  ('Greg:Showing my friends AudioBoo http://audioboo.fm/ Everyone seems 2 love it. Ta for the headzup bro. So need 2 get iPhone. Roll on June',
#   {'entities': [[70, 74, 'love']]}),
#  ('Sometimes all it takes to solve our problems is a fresh morning!! Hope today is beautiful for you',
#   {'entities': [[66, 97, 'Hope today is beautiful for you']]}),
#  ('_Cera That is so awesome  awwww.', {'entities': [[17, 24, 'awesome']]}),
#  (' Sounds pretty cool. Great job man!',
#   {'entities': [[21, 35, 'Great job man!']]}),
#  (' Oh, I see!  So it`s like, morning there, right? Happy breakfast! *thumbs up*',
#   {'entities': [[47, 54, '? Happy']]}),
#  ('says gud eve guys.. lets play poker yeah!! cant read my poker face  http://plurk.com/p/sw4yq',
#   {'entities': [[0, 19, 'says gud eve guys..']]}),
#  ('_joy it`s entirely possible',
#   {'entities': [[0, 27, '_joy it`s entirely possible']]}),
#  ('May the forth be with you .....',
#   {'entities': [[0, 31, 'May the forth be with you .....']]}),
#  (' Cavs has the easier route than Denver.',
#   {'entities': [[14, 26, 'easier route']]}),
#  ('_nickj07 Um....Nicks Voice,Smile,Eyes,Laugh,and Hes a Great Rolemodel',
#   {'entities': [[54, 59, 'Great']]}),
#  (' i canï¿½t choose one  i love all the songs on LV&TT;bt if u like... Read More: http://is.gd/JkVF',
#   {'entities': [[23, 43, 'i love all the songs']]}),
#  (' Hey guys! can i ask; what item did u guys put up for ur talent show? i am such a BIG fans of both of you! whoo!',
#   {'entities': [[86, 90, 'fans']]}),
#  (' Makes sense, I`d totally show off a girlfriend by asking her to wear her high school prom dress',
#   {'entities': [[1, 13, 'Makes sense,']]}),
#  ('Photo: I like da cooolooorss and the composition is great  scribkin: http://tumblr.com/xyb1qw8cb',
#   {'entities': [[7,
#      57,
#      'I like da cooolooorss and the composition is great']]}),
#  ('wishing I got fij', {'entities': [[0, 17, 'wishing I got fij']]}),
#  (' hahaha thaanks!  iï¿½m from brazil!', {'entities': [[8, 16, 'thaanks!']]}),
#  (' don`t ask  Hoping that today will be an improvment on the rest of the week. Looking forward to the weekend weather!',
#   {'entities': [[75, 92, '. Looking forward']]}),
#  (' really good, but it`s definitely not a 12`s. So many people getting burned alive',
#   {'entities': [[1, 13, 'really good,']]}),
#  ('Rachel Allens date bars, so easy to make   http://twitpic.com/4jas7',
#   {'entities': [[28, 32, 'easy']]}),
#  (' that was so much fun! the banana dessert alone is worth the trip to austin! we`ll be back soon',
#   {'entities': [[18, 22, 'fun!']]}),
#  ('dad wants the computer, so I`d best be off  taking my lapity-topity to a mac specialist tomorrow, hopefully they make teh owwie go awayz',
#   {'entities': [[31, 35, 'best']]}),
#  (' http://twitpic.com/4w0yj - wow, fancy!',
#   {'entities': [[28, 39, 'wow, fancy!']]}),
#  ('Just found out my kitty isn`t pregnant  its a good thing though, we are going to adopt one instead',
#   {'entities': [[46, 50, 'good']]}),
#  (' blah blah blah.... just kidding dude  i`ve never had anyone offer up their stem cells before haha!',
#   {'entities': [[92, 98, 'e haha']]}),
#  (' you are such a beautiful bride! you`re gonna love the married life. it absolutely rocks! congrats to you both.',
#   {'entities': [[1, 32, 'you are such a beautiful bride!']]}),
#  ('bowling with cousins  awesome', {'entities': [[22, 29, 'awesome']]}),
#  ('has two tickets to Amadou and Miriam for Tue. June 2 that I can`t use  $25 each to anyone who wants `em. That`s face value. Should be good',
#   {'entities': [[134, 138, 'good']]}),
#  (' I can`t believe that he almost got put down, before the rescue group went and got him.',
#   {'entities': [[57, 87, 'rescue group went and got him.']]}),
#  ('ah what a lovely day for a bike ride and cake making  *is rooting 4 those who are revising!* do your best! X',
#   {'entities': [[0,
#      108,
#      'ah what a lovely day for a bike ride and cake making  *is rooting 4 those who are revising!* do your best! X']]}),
#  (' http://twitpic.com/2dmtn - I saw this pic and it reminded me of you in Anna and the King.. so cuuuute little fella',
#   {'entities': [[92, 115, 'so cuuuute little fella']]}),
#  ('Happy Mama`s day to all mothers', {'entities': [[0, 5, 'Happy']]}),
#  ('The Eagles make saturday nights so much better.',
#   {'entities': [[0, 47, 'The Eagles make saturday nights so much better.']]}),
#  (' She does especially Pink ones LOL  What beautiful creatures they are!',
#   {'entities': [[39, 50, 't beautiful']]}),
#  ('says again.. happy mothers day to all your moms  http://plurk.com/p/svdsh',
#   {'entities': [[13, 30, 'happy mothers day']]}),
#  ('boopboopboop. still talking to ashley & brittany.  i`ve been talking to ashley for forever, and our convo still goes places. we`re awesome',
#   {'entities': [[125, 138, 'we`re awesome']]}),
#  (' briliant! May the fourth be with you  #starwarsday #starwars',
#   {'entities': [[1, 37, 'briliant! May the fourth be with you']]}),
#  (' grrrrri want you to come  kiss justice for me !!!',
#   {'entities': [[1,
#      50,
#      'grrrrri want you to come  kiss justice for me !!!']]}),
#  ('What a fun night', {'entities': [[0, 16, 'What a fun night']]}),
#  (' this is very true about ! but you do have to admit it was pret-ty funny! im bout to go you tube it!  lol',
#   {'entities': [[67, 73, 'funny!']]}),
#  (' I think that boat sailed my friend... The few CCO`s that had them, had them months ago....  I wish you luck though...',
#   {'entities': [[93, 118, 'I wish you luck though...']]}),
#  (' I`m good! thx.  and how are u? what are u doing?',
#   {'entities': [[5, 10, 'good!']]}),
#  ('Handed in. Can relax a bit now.',
#   {'entities': [[11, 31, 'Can relax a bit now.']]}),
#  ('Respect to  for the Heineken man bag  http://twitpic.com/4jdrg',
#   {'entities': [[0, 7, 'Respect']]}),
#  (' I know!! our cats could be family  mikesh is so cute!!',
#   {'entities': [[40, 55, 'sh is so cute!!']]}),
#  ('Mother`s Day Wishes from google... Pretty & beautiful flowers on google logo  http://www.google.co.in/',
#   {'entities': [[44, 53, 'beautiful']]}),
#  ('HAPPY MOTHER DAY JANEY! EVEN THOUGH IDK IF YOUR A MOMMY!',
#   {'entities': [[0, 5, 'HAPPY']]}),
#  (' I know!  I loved it.', {'entities': [[10, 17, 'I loved']]}),
#  ('  ha ha, and what game is that? i like games',
#   {'entities': [[30, 38, '? i like']]}),
#  (' well gracias  haha and why is that? the plays?',
#   {'entities': [[12, 19, 's  haha']]}),
#  ('got it? good. HAPPY MOTHERS DAY!', {'entities': [[14, 19, 'HAPPY']]}),
#  ('watching snl with my ucsd girls and laughing about twitter/blackberry jokes  thought i`d tweet that.',
#   {'entities': [[36, 44, 'laughing']]}),
#  (' just make sure you have it well done',
#   {'entities': [[28, 37, 'well done']]}),
#  ('Today I wrote two songs (one for temple which I will probably never perform ever) and one for mothers day. Happy vesak everyone  rena xoxo',
#   {'entities': [[107, 115, 'Happy ve']]}),
#  ('_AM Well what can I say - you do look Hot in your pic... That`s gotta work for most of us...',
#   {'entities': [[26,
#      92,
#      'you do look Hot in your pic... That`s gotta work for most of us...']]}),
#  ('  i`ve seen inkheart- i liked it too', {'entities': [[22, 29, 'i liked']]}),
#  ('about to go to acting school  yayay', {'entities': [[30, 35, 'yayay']]}),
#  (' Yes! That sounds like a great idea. Message me on LJ about it',
#   {'entities': [[25, 30, 'great']]}),
#  ('i wish i was at the beach already', {'entities': [[2, 6, 'wish']]}),
#  ('When you think about it, the way God works in tremendously, amazing -- He made it possible for me to get my card holder that I lost back.',
#   {'entities': [[46, 67, 'tremendously, amazing']]}),
#  (' Oh dear, it will be late there.... good ol Michigan!  Well I look forward to chatting with you when our wakeful hours overlap.',
#   {'entities': [[58, 74, 'l I look forward']]}),
#  ('I just saw a shooting star... I made my wish',
#   {'entities': [[40, 44, 'wish']]}),
#  ('is going to help lancey cook', {'entities': [[12, 16, 'help']]}),
#  ('Back from x-men origins . Was surprisingly good',
#   {'entities': [[43, 47, 'good']]}),
#  (' I love sausage too  #kitchenfire', {'entities': [[3, 7, 'love']]}),
#  (' Cool Guide.. My best Tip.. Do NOT Use Them Unless Absolutely Needed !!!',
#   {'entities': [[14, 26, 'My best Tip.']]}),
#  ('I wish my grandmother had taken me to the US with her',
#   {'entities': [[2, 6, 'wish']]}),
#  ('Excited!!! Trousers on their way from Topshop, should be here in a couple of days',
#   {'entities': [[0, 10, 'Excited!!!']]}),
#  ('Apple is expected to launch a new iPhone this summer.  Hi my name is Judy and I am addicted to Apple products.',
#   {'entities': [[9, 17, 'expected']]}),
#  ('Score two days I get more food stamps good cause i want a safeway pizza',
#   {'entities': [[38, 42, 'good']]}),
#  (' Aw you are and you`re welcome',
#   {'entities': [[1, 30, 'Aw you are and you`re welcome']]}),
#  ('Just finishing shooting, can u believe it, but got the job done',
#   {'entities': [[43, 63, 'but got the job done']]}),
#  ...]
