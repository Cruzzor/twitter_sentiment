# %%
import re
# Tutorial about Python regular expressions: https://pymotw.com/2/re/ import string
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import nltk
import spacy
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %% [markdown]
# Reference: https://www.kaggle.com/rohitsingh9990/ner-training-using-spacy-ensemble

# %%
BASE_PATH = '../../data/'

train_df = pd.read_csv(BASE_PATH + 'train.csv')
test_df = pd.read_csv( BASE_PATH + 'test.csv')
submission_df = pd.read_csv( BASE_PATH + 'sample_submission.csv')

train_df.dropna(inplace=True)

# %%
def save_model(output_dir, nlp, new_model_name):
    output_dir = f'../../models/{output_dir}'
    if output_dir is not None:        
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        nlp.meta["name"] = new_model_name
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

# %%
def train(train_data, output_dir, n_iter=20, model=None):
    """Load the model, set up the pipeline and train the entity recognizer."""
    ""
    if model is not None:
        nlp = spacy.load(output_dir)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")
    
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")
    
    # add labels
    for _, annotations in train_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # sizes = compounding(1.0, 4.0, 1.001)
        # batch up the examples using spaCy's minibatch
        if model is None:
            nlp.begin_training()
        else:
            nlp.resume_training()

        for itn in tqdm(range(n_iter)):
            random.shuffle(train_data)
            batches = minibatch(train_data, size=compounding(4.0, 500.0, 1.001))    
            losses = {}
            for batch in batches:
                texts, annotations = zip(*batch)
                print(f"Texts: {texts}")
                print(f"Annotations: {annotations}")
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,   # dropout - make it harder to memorise data
                    losses=losses, 
                )
            
            print("Losses", losses)
    save_model(output_dir, nlp, 'st_ner')

# %%
def get_model_out_path(sentiment):
    model_out_path = None
    if sentiment == 'positive':
        model_out_path = 'model_pos'
    elif sentiment == 'negative':
        model_out_path = 'model_neg'
    else:
        model_out_path = 'model_neu'
    return model_out_path

# %%
def get_training_data(sentiment):
    train_data = []
    for index, row in train_df.iterrows():
        if row.sentiment == sentiment:
            selected_text = row.selected_text
            text = row.text
            start = text.find(selected_text)
            end = start + len(selected_text)
            train_data.append((text, {"entities": [[start, end, selected_text]]}))
    return train_data

# %% [markdown]
# ---------------

# %%
train_data = get_training_data("positive")
model_path = get_model_out_path("positive")

train_data
# Out:
# [('2am feedings for the baby are fun when he is all smiles and coos',
#   {'entities': [[30, 33, 'fun']]}),
#  (' Journey!? Wow... u just became cooler.  hehe... (is that possible!?)',
#   {'entities': [[11, 39, 'Wow... u just became cooler.']]}),
#  ('I really really like the song Love Story by Taylor Swift',
#   {'entities': [[16, 20, 'like']]}),
#  ('Playing Ghost Online is really interesting. The new updates are Kirin pet and Metamorph for third job.  Can`t wait to have a dragon pet',
#   {'entities': [[31, 43, 'interesting.']]}),
#  ('the free fillin` app on my ipod is fun, im addicted',
#   {'entities': [[0,
#      51,
#      'the free fillin` app on my ipod is fun, im addicted']]}),
#  ('juss came backk from Berkeleyy ; omg its madd fun out there  havent been out there in a minute . whassqoodd ?',
#   {'entities': [[46, 49, 'fun']]}),
#  ('I`m going home now. Have you seen my new twitter design? Quite....heavenly isn`****?',
#   {'entities': [[57, 74, 'Quite....heavenly']]}),
#  ('i hope unni will make the audition . fighting dahye unni !',
#   {'entities': [[2, 6, 'hope']]}),
#  (' That`s very funny.  Cute kids.', {'entities': [[13, 19, 'funny.']]}),
#  ('A little happy for the wine jeje ok it`sm my free time so who cares, jaja i love this day',
#   {'entities': [[0, 17, 'A little happy fo']]}),
#  ('im an avid fan of **** magazine and i love your magazines',
#   {'entities': [[6, 17, 'avid fan of']]}),
#  (' I love to! But I`m only available from 5pm.  and where dear? Would love to help  convert her vids.ï¿½',
#   {'entities': [[1, 11, 'I love to!']]}),
#  (' romance zero is funny', {'entities': [[1, 22, 'romance zero is funny']]}),
#  ('What better way to spoil mum than to let her kick back and relax over a nice meal and a bottle of her favorite wine? Our wine was a red',
#   {'entities': [[102, 110, 'favorite']]}),
#  ('  He`s awesome... Have you worked with him before? He`s a good friend.',
#   {'entities': [[5, 14, 's awesome']]}),
#  ('Chilliin', {'entities': [[0, 8, 'Chilliin']]}),
#  (' a celtics-lakers rematch sounds better don`t you think? lol',
#   {'entities': [[33, 39, 'better']]}),
#  (' THANK YYYYYYYYYOOOOOOOOOOUUUUU!',
#   {'entities': [[1, 32, 'THANK YYYYYYYYYOOOOOOOOOOUUUUU!']]}),
#  (' lucky kid...i so wanna see loserville  pity im in oz....',
#   {'entities': [[1, 6, 'lucky']]}),
#  ('Happy Star Wars day everyone! and Enjoy the holiday (UK)',
#   {'entities': [[0,
#      56,
#      'Happy Star Wars day everyone! and Enjoy the holiday (UK)']]}),
#  (' Well what im working on isn`t QUITE ready to post about publicly (still beta testing) but its a cool new script I coded',
#   {'entities': [[97, 101, 'cool']]}),
#  (' SWEEEEET - San Fran is awesome!!!!  Love it there',
#   {'entities': [[37, 50, 'Love it there']]}),
#  ('Happy Mothers day to all you Mums out there',
#   {'entities': [[0, 43, 'Happy Mothers day to all you Mums out there']]}),
#  (' We saw that in none 3D - the baddie`s the best',
#   {'entities': [[43, 47, 'best']]}),
#  ('4am. And Im on the beach. Pretty', {'entities': [[26, 32, 'Pretty']]}),
#  (" Awesome.  I`m down in Ocean Beach (if you know where that is.) By the way. 'YourBiggestFan' I`m a re-al big fan of you-rs.",
#   {'entities': [[1, 9, 'Awesome.']]}),
#  (' haha I do not know how to work blip apart from the obvious! thanks for reblipping my song  have a nice day ****',
#   {'entities': [[61, 67, 'thanks']]}),
#  (' have a safe trip joshy poo.......you`ll knock them dead at your speech',
#   {'entities': [[8, 12, 'safe']]}),
#  (' woof, I wish I was allowed to go',
#   {'entities': [[7, 33, 'I wish I was allowed to go']]}),
#  ('Thank you, Afrin Nasal Spray! Also, I got a giant teacup tonight!',
#   {'entities': [[0, 10, 'Thank you,']]}),
#  ('Aww, I love my daddy! He works 7 days a week almost all day and still tries to go to SF with all of us',
#   {'entities': [[5, 14, 'I love my']]}),
#  (' hahaa your awesomee !', {'entities': [[1, 22, 'hahaa your awesomee !']]}),
#  ('holy smokes! star trek was freaking awesomeeeee',
#   {'entities': [[36, 47, 'awesomeeeee']]}),
#  (' Not a prob hun', {'entities': [[1, 11, 'Not a prob']]}),
#  (' hey mia!  totally adore your music.  when will your cd be out?',
#   {'entities': [[17, 24, 'y adore']]}),
#  ('Shopping. Cleaning. BMFing. Webcam chatting with nephews. Nothing spesh, but a good bank holiday Monday nonetheless',
#   {'entities': [[79, 83, 'good']]}),
#  (' =O you need to ask him something? Lmao I love him too',
#   {'entities': [[40, 54, 'I love him too']]}),
#  (' Nice to see you tweeting!  It`s Sunday 10th May and we`re celebrating Mother`s Day here today. So be nice to yer Mom',
#   {'entities': [[100, 106, 'e nice']]}),
#  ('decided 2 trans frm relaxed 2 natural hair but i wish my whole head looked like my roots.  Age of the instant gratification....',
#   {'entities': [[47, 53, 'i wish']]}),
#  ('Candle wax is very enjoyable.', {'entities': [[19, 29, 'enjoyable.']]}),
#  (' She`s unassuming and unpretentious. She`s just, as. I suppose that`s why she`s so endearing--because we can relate to her',
#   {'entities': [[83, 93, 'endearing-']]}),
#  ('goooooddd morning tweets!!  week three OF my workout. did i mention i got my new glasses yesterday?!?',
#   {'entities': [[0, 26, 'goooooddd morning tweets!!']]}),
#  (' fine! Going to do my big walk today 20 or so miles',
#   {'entities': [[1, 6, 'fine!']]}),
#  ('_Laurie sending love, blessings & healing thoughts to you & family  peace',
#   {'entities': [[8,
#      73,
#      'sending love, blessings & healing thoughts to you & family  peace']]}),
#  ('  #lichfield #tweetup sounds like fun  Hope to see you and everyone else there!',
#   {'entities': [[20, 37, 'p sounds like fun']]}),
#  ('Few Bevvies 2day in twn..great on a day off!!',
#   {'entities': [[25, 30, 'great']]}),
#  ('first night in myers. just not the same w/out lydia!  but i`m actually excited about this summer!',
#   {'entities': [[71, 78, 'excited']]}),
#  (' good morning', {'entities': [[1, 13, 'good morning']]}),
#  (' its the best show EVER!',
#   {'entities': [[1, 24, 'its the best show EVER!']]}),
#  ('who watched X-men origins: wolverine? i totally loved it! haha',
#   {'entities': [[38, 57, 'i totally loved it!']]}),
#  (' I VOTED!!! do u have a personal myspace? i keep talking to fakes   i <3 you. u helped me thru the hrdest time of my life! (: x',
#   {'entities': [[68,
#      122,
#      'i <3 you. u helped me thru the hrdest time of my life!']]}),
#  ('happy 1 year! <3', {'entities': [[0, 16, 'happy 1 year! <3']]}),
#  ('Oh, I HELLA forgot to say my official good morning  Like to hear it? Here it go! Goooooooooooood Morrrrrrrrning Twitterville! Lol',
#   {'entities': [[81, 111, 'Goooooooooooood Morrrrrrrrning']]}),
#  (' nite nite bday girl  have fun at concert',
#   {'entities': [[25, 30, 'e fun']]}),
#  ('happy mother`s day to all moms out there...',
#   {'entities': [[0, 5, 'happy']]}),
#  ('im thinking that im going to have fun tonight....and maybe some changes are coming',
#   {'entities': [[20, 37, 'going to have fun']]}),
#  (' Haha I know, I cant handle the fame!  and thank you!',
#   {'entities': [[41, 53, 'd thank you!']]}),
#  (' yes! sober HAHAHA tanghaling tapat dude! haha WILD. i don`t knowwww  plan plan  before you go to US!',
#   {'entities': [[12, 18, 'HAHAHA']]}),
#  (' We never miss ICarly - my son has a huge crush on Miranda',
#   {'entities': [[42, 47, 'crush']]}),
#  ('Feeling smooth like chrome', {'entities': [[0, 14, 'Feeling smooth']]}),
#  ('JONAS BROTHERS - Live to party.                It`s rocking so hard     I love the song,',
#   {'entities': [[0,
#      67,
#      'JONAS BROTHERS - Live to party.                It`s rocking so hard']]}),
#  ('happy mother`s day to all the mothers in the world.',
#   {'entities': [[0, 5, 'happy']]}),
#  ('35mins through the 1hr 20mins Google Wave demo, that looks a lot of fun, would love to test it though.  http://bit.ly/WnMSc',
#   {'entities': [[73, 102, 'would love to test it though.']]}),
#  ('Sleepy Tabz is heading to bed.  Fun night! Listened through the next episode of Joss`d!',
#   {'entities': [[32, 42, 'Fun night!']]}),
#  ('Screw the reviews, I thought Wolverine was awesome. But not enough Dominic Monaghan for my liking.',
#   {'entities': [[19, 51, 'I thought Wolverine was awesome.']]}),
#  ('If you followed us recently, PLEASE dont be offended that we haven`t followed back. We hit our limit.   Hopefully we will be free soon.',
#   {'entities': [[104, 113, 'Hopefully']]}),
#  ('Happy monday  up and about going to tavares today. Hope everyone has a blessed day!',
#   {'entities': [[0, 5, 'Happy']]}),
#  (' http://twitpic.com/4jaz5 - Cool... luv it',
#   {'entities': [[36, 39, 'luv']]}),
#  ('  that`s why I need to be there...To represent the Blackberries',
#   {'entities': [[2, 31, 'that`s why I need to be there']]}),
#  (' yeah I was thinking about that ,ahaha',
#   {'entities': [[32, 38, ',ahaha']]}),
#  ('almost died. Laptop screen was set to 100% brightness after I reinstalled Windows Vista. Got a headache now  #insanedefaults',
#   {'entities': [[7, 12, 'died.']]}),
#  ('discovered cause of a bug in the new #NetPLAYER 4 build. Publishing bug fix now, hopefully new beta by tomorrow',
#   {'entities': [[81, 90, 'hopefully']]}),
#  ('writing report cards  soooo tired but what an amazing day. check it out on fb soon!',
#   {'entities': [[38, 58, 'what an amazing day.']]}),
#  ('Well good morning all, What a wonderful day in the neighborhood  Thanks for all those that are now following another 60 this morning',
#   {'entities': [[0,
#      132,
#      'Well good morning all, What a wonderful day in the neighborhood  Thanks for all those that are now following another 60 this morning']]}),
#  ('FTSK and Mercy Mercedes were amazing tonight.. as always',
#   {'entities': [[24, 46, 'were amazing tonight..']]}),
#  ('  hope he is ok!', {'entities': [[2, 6, 'hope']]}),
#  ('can`t school just be done already? it hurts too much... seeing him every day',
#   {'entities': [[35, 55, 'it hurts too much...']]}),
#  ('Went to a party last night. Dindin and I showed up in matching outfits ) GREAT MINDS THINK ALIKE ) Anyway, happy birthday, ate lara',
#   {'entities': [[73, 78, 'GREAT']]}),
#  (' Happy b-day! Just woke up on this side of Earth, so wishes are bit late',
#   {'entities': [[1, 13, 'Happy b-day!']]}),
#  ('thank you for teaching me values and to be a better person each day  I LOVE SO MUCH, YOU`RE THE BEST MUM IN THE WORLD',
#   {'entities': [[0, 5, 'thank']]}),
#  ('HAPPY MOTHERS DAY.!', {'entities': [[0, 5, 'HAPPY']]}),
#  (' *laughs* I`m glad that you have self confidence - it`s a wonderful trait to have  I`ll applaud extra loud for it, okay?',
#   {'entities': [[14, 18, 'glad']]}),
#  ('  Thanks', {'entities': [[2, 8, 'Thanks']]}),
#  ('Getting ready for week  Its too nice today to be stuck inside working!',
#   {'entities': [[24, 36, 'Its too nice']]}),
#  ('Happy Mothers Day people. i love my mom a lot still',
#   {'entities': [[0,
#      51,
#      'Happy Mothers Day people. i love my mom a lot still']]}),
#  (' That`s awesome dude, yay for surprise celebrities!  I got to meet him a few years ago, he was soooo friendly.',
#   {'entities': [[86, 110, ', he was soooo friendly.']]}),
#  (' it makes me happy to hear a girl talk, or tweet, about the nba. but... could you give my nuggets some love?!',
#   {'entities': [[13, 18, 'happy']]}),
#  ('Watching Ellen Love her!! then doing the dishes  and tanning ...it`s gorgeous out!',
#   {'entities': [[63, 82, '.it`s gorgeous out!']]}),
#  ('tonight in party w/ my girls (minus vita)',
#   {'entities': [[0, 41, 'tonight in party w/ my girls (minus vita)']]}),
#  (' I saw the play of it here, it was amazing',
#   {'entities': [[35, 42, 'amazing']]}),
#  (' _ i am glad to break my twitter virginity with you two.',
#   {'entities': [[8, 12, 'glad']]}),
#  (' I know   It was worth a shot, though!',
#   {'entities': [[14, 21, 'as wort']]}),
#  ('Just opened a facebook account, I`m a little confused I don`t really get it. Twitter seems much better',
#   {'entities': [[96, 102, 'better']]}),
#  ('DUSTBIN BABY ON AT 11.30 Cannot wait  x',
#   {'entities': [[25, 36, 'Cannot wait']]}),
#  ('Before I get too distracted, I`d like to thank my new followers for taking the trouble to follow me! And to my others: feelin the love',
#   {'entities': [[0,
#      134,
#      'Before I get too distracted, I`d like to thank my new followers for taking the trouble to follow me! And to my others: feelin the love']]}),
#  ('mcfly gig last nightt omg it was amazin didnt sit down through the whole thing  mcfly did you see me and ma best mate we were in tutus',
#   {'entities': [[26, 39, 'it was amazin']]}),
#  (' doing pretty well, up and wide awake',
#   {'entities': [[1, 19, 'doing pretty well,']]}),
#  ('My frist post... Off to find a new car for my parents, exciting!',
#   {'entities': [[55, 64, 'exciting!']]}),
#  (' oh nice going!', {'entities': [[1, 15, 'oh nice going!']]}),
#  ('Gonna celebrate Mothers Day with the family but gonna start the partying tonite',
#   {'entities': [[64, 72, 'partying']]}),
#  (' i agree with you!', {'entities': [[1, 18, 'i agree with you!']]}),
#  ('90 degrees, gross skies, and thunderstorms...perfect match for my mood  lol',
#   {'entities': [[45, 55, 'perfect ma']]}),
#  ('_2nd aww thanks!', {'entities': [[9, 16, 'thanks!']]}),
#  ('Please Review Sunehre Ad Placement  http://tinyurl.com/oow6mk',
#   {'entities': [[0, 9, 'Please Re']]}),
#  ('aww  you loooove me', {'entities': [[0, 19, 'aww  you loooove me']]}),
#  ('awesome lucky you', {'entities': [[0, 17, 'awesome lucky you']]}),
#  (' haha im jewish, i love that one', {'entities': [[19, 23, 'love']]}),
#  ('Cant wait to see my boy tomorrow', {'entities': [[0, 9, 'Cant wait']]}),
#  ('Omg Wango Tango was **** AWSOME! I love my baby for taking me',
#   {'entities': [[0,
#      61,
#      'Omg Wango Tango was **** AWSOME! I love my baby for taking me']]}),
#  ('Version 2 of our live, interactive Trans-Siberian ticket planner is launched: http://tinyurl.com/c5ljwm - its very cool',
#   {'entities': [[106, 119, 'its very cool']]}),
#  ('_30439 I really wish I could go!', {'entities': [[16, 20, 'wish']]}),
#  ('  This has made my night!!  Way too funny!!',
#   {'entities': [[2, 42, 'This has made my night!!  Way too funny!']]}),
#  ('Woo CAVS.  Happy Mother`s Day!', {'entities': [[11, 16, 'Happy']]}),
#  (' Thanks for the warm welcome! We didn`t make plans   because our arrival time was so up in the air.',
#   {'entities': [[1, 7, 'Thanks']]}),
#  (' Have a good one', {'entities': [[1, 15, 'Have a good on']]}),
#  (' yep infact she is popular, miss india 99, talented film actress .... and lot more',
#   {'entities': [[12, 27, 'she is popular,']]}),
#  ('Daniel has won DSDS. His voice is great.',
#   {'entities': [[21, 40, 'His voice is great.']]}),
#  ('_x_ATL u mean jack barakat`s?! wow so have u ever gone to his house? Hehe i mean ur ssoo lucky to have the address!',
#   {'entities': [[89, 94, 'lucky']]}),
#  ('I sure do hope it becomes 4:20 this afternoon ...',
#   {'entities': [[0, 14, 'I sure do hope']]}),
#  (' it means that you are now FAMOUS. Congrats!',
#   {'entities': [[35, 44, 'Congrats!']]}),
#  ('I have such fantastic friends, including several ones met through here! thanks for being in my life - you are such amazing people!',
#   {'entities': [[102, 130, 'you are such amazing people!']]}),
#  ('tamlyn wishes she was as cool as my sock draw',
#   {'entities': [[25, 29, 'cool']]}),
#  ('Yes, I love tea. If that makes me typically English then so be it',
#   {'entities': [[0, 16, 'Yes, I love tea.']]}),
#  (' a mouth for sure', {'entities': [[1, 17, 'a mouth for sure']]}),
#  (' pancakes!! with lemon and sugar thanks!',
#   {'entities': [[33, 40, 'thanks!']]}),
#  (' Yay, three followers! Good to know more than one person in this big wide world likes fishies.',
#   {'entities': [[23, 27, 'Good']]}),
#  ('Goodmorning', {'entities': [[0, 11, 'Goodmorning']]}),
#  (' I love mine, too . happy motherï¿½s day to your mom , John Taylor  . much love to you, too .',
#   {'entities': [[1,
#      91,
#      'I love mine, too . happy motherï¿½s day to your mom , John Taylor  . much love to you, too']]}),
#  ('http://twitpic.com/4wukt - We bought Ludi her own rug. Dogs are the best',
#   {'entities': [[68, 72, 'best']]}),
#  ('loves her mum very much! Happy Mothers Day to all the wonderful mothers out there',
#   {'entities': [[0,
#      81,
#      'loves her mum very much! Happy Mothers Day to all the wonderful mothers out there']]}),
#  ('i have an urge to play wow but i have to wait 2 weeks til im at my dads! 5+47DAYS TIL MCFLY, im so excited  (L)',
#   {'entities': [[99, 106, 'excited']]}),
#  ('Morning tweeple', {'entities': [[0, 15, 'Morning tweeple']]}),
#  (' Now you only have 2 hours to sleep...  - Rest if you need it.',
#   {'entities': [[40, 62, '- Rest if you need it.']]}),
#  ('Is heading home from foot surgery and wishing she had a boyfriend to come over and cuddle with',
#   {'entities': [[38, 45, 'wishing']]}),
#  (' lol. just don`t ever forget me', {'entities': [[1, 5, 'lol.']]}),
#  ('   Wow what a beautiful picture... and by the way....I am straight....just wanted to let you know!!!     Bella',
#   {'entities': [[3, 30, 'Wow what a beautiful pictur']]}),
#  ('In Arch. Drawing. Checking out MVCC`s CAD degree. Looks good to me',
#   {'entities': [[50, 60, 'Looks good']]}),
#  (' you know you want to come keep me company whilst mum`s at her friends for the night  it`s such a nice evening!',
#   {'entities': [[96, 102, 'a nice']]}),
#  ('cooking with my dad  having lots of fun in the kitchen together',
#   {'entities': [[21, 39, 'having lots of fun']]}),
#  ('Off to Woolsery this morning to (hopefully) see North Molton U16 clinch the North Devon League title. Lovely day for it',
#   {'entities': [[102, 119, 'Lovely day for it']]}),
#  ('  you`re missing out, bb! i`m such a cereal nut, i think i like every kind available.',
#   {'entities': [[57, 63, 'i like']]}),
#  ('Just woke up :o mums singing to her new gn`r cd replacement i bought because im a good daughter',
#   {'entities': [[77, 95, 'im a good daughter']]}),
#  ('250 miles down, only 1750 to go. Thats ok, u2 on the radio alwas helps.',
#   {'entities': [[59, 71, 'alwas helps.']]}),
#  (' FIL 461 with cool people like me', {'entities': [[14, 18, 'cool']]}),
#  ('Good Morning!!! Work and then it`s ESPN`s Sunday night Baseball. hopefully it won`t get rained out',
#   {'entities': [[0, 4, 'Good']]}),
#  ('Why kiss the feet of the people who kick you when you can be anything that you want to?  morning everyone! Hope you have the best day ever',
#   {'entities': [[125, 129, 'best']]}),
#  (' congratulations ! you guys finish a month early than we do. booo',
#   {'entities': [[1, 16, 'congratulations']]}),
#  ('workin a long day today... hopefully i can make some good tips',
#   {'entities': [[27, 62, 'hopefully i can make some good tips']]}),
#  (' Thanks for the support',
#   {'entities': [[1, 23, 'Thanks for the support']]}),
#  ('had a good day driving up mountains, visiting katie, eating chips & fudge and stocking up on lovely smelling soaps',
#   {'entities': [[93, 99, 'lovely']]}),
#  ('Nyappy mother`s day to your mom`s.',
#   {'entities': [[0, 34, 'Nyappy mother`s day to your mom`s.']]}),
#  ('_Libertine um, glad you enjoyed it...', {'entities': [[15, 19, 'glad']]}),
#  (' sounds like you all had a great night . i`m glad it was successful',
#   {'entities': [[41, 49, 'i`m glad']]}),
#  (' Thanks for sharing that', {'entities': [[1, 7, 'Thanks']]}),
#  (' you should say mlia instead of fml  i hope you find it soon',
#   {'entities': [[37, 43, 'i hope']]}),
#  ('Garden going well, almost all the corn and peas are up, no onions or beets up yet though.',
#   {'entities': [[13, 18, 'well,']]}),
#  ('Ahhh i`m sqeaky clean and fresh. Even though i`m wearing dirty clothes  I love Two and a Half Men - it`s amazing!',
#   {'entities': [[0,
#      113,
#      'Ahhh i`m sqeaky clean and fresh. Even though i`m wearing dirty clothes  I love Two and a Half Men - it`s amazing!']]}),
#  (' WE Quite Like Worthing its a relaxing place with nice coffee shops and fresh air.. and not too many Oiks',
#   {'entities': [[24, 44, 'its a relaxing place']]}),
#  ('today was a lovely day! I had fun with  and  this evening!',
#   {'entities': [[12, 18, 'lovely']]}),
#  (' it was amazing', {'entities': [[1, 15, 'it was amazing']]}),
#  (' I feel for you  I hope it`s a smooth flight. Be safe! Mucho amor from Boston!',
#   {'entities': [[1,
#      53,
#      'I feel for you  I hope it`s a smooth flight. Be safe']]}),
#  (' sweet dreams', {'entities': [[1, 13, 'sweet dreams']]}),
#  (' haha thanks  its for history and its on how the invention of television has influence america lol',
#   {'entities': [[1,
#      98,
#      'haha thanks  its for history and its on how the invention of television has influence america lol']]}),
#  (' Like your pics, Lucky Girl, again', {'entities': [[1, 5, 'Like']]}),
#  ('Feeling loved!  My Mom got me a Nikon Cool Pix for my birthday!!!!',
#   {'entities': [[8, 14, 'loved!']]}),
#  ('And the Sun is shinning.........at last',
#   {'entities': [[8, 39, 'Sun is shinning.........at last']]}),
#  ('_a_michael Hey! thanks for another great day! I`m going to sleep now! I`ll chat with you tomorrow!  Sweet dreams!',
#   {'entities': [[16, 45, 'thanks for another great day!']]}),
#  (' http://twitpic.com/4v0vr - cool! you and your mother have awesome hair styles,! Wish her a happy mother`s day!',
#   {'entities': [[59, 66, 'awesome']]}),
#  ('happy mother`s day mothers.', {'entities': [[0, 5, 'happy']]}),
#  ('just came back from karaoke & eating dinner with emily. it was sooooo much fun',
#   {'entities': [[75, 78, 'fun']]}),
#  (' Discrimination is not a bad thing. I`ve learned to say no. My children would say I mastered that years ago',
#   {'entities': [[1, 35, 'Discrimination is not a bad thing.']]}),
#  ('Just got back from working out. I`m feeling pretty good. work at 4:30',
#   {'entities': [[0,
#      56,
#      'Just got back from working out. I`m feeling pretty good.']]}),
#  (' So!!! Why should that matter? I bet you would be GREAT at it! I do!!! It`s what you love, right? Why not go for it!',
#   {'entities': [[1,
#      116,
#      'So!!! Why should that matter? I bet you would be GREAT at it! I do!!! It`s what you love, right? Why not go for it!']]}),
#  ('DH is just about finished making his giant Trio candy bar. Thank the heavens. His work mates are in for a treat tomorrow!',
#   {'entities': [[59, 77, 'Thank the heavens.']]}),
#  ('I love when ryans a housewife. Makes me smile.',
#   {'entities': [[37, 46, 'me smile.']]}),
#  (' .. .great.. you can buy me lunch when i get my 10-15% pay cut next month..',
#   {'entities': [[4, 11, '.great.']]}),
#  ('finally gone to the beach, yeaaaah!',
#   {'entities': [[0, 35, 'finally gone to the beach, yeaaaah!']]}),
#  ('_ranjan Did I ever mention what a nice and awesome dude you are?',
#   {'entities': [[43, 50, 'awesome']]}),
#  (' Hello Gorgeous GIRL! Nice new pic!  HOw are you today',
#   {'entities': [[7, 21, 'Gorgeous GIRL!']]}),
#  ('Ok that **** duet was hysterical LOL',
#   {'entities': [[22, 32, 'hysterical']]}),
#  (' either way, you always tend to make my #followfriday list, sweetie - you do rock that much',
#   {'entities': [[70, 91, 'you do rock that much']]}),
#  ('watched 100th episode of numb3rs. loved how they did a throwback to the first episode, using the sprinkler theory',
#   {'entities': [[34, 39, 'loved']]}),
#  ('_Ichigo She tried to carry on aswell, bless, I suppose maybe that`s why kids shouldn`t be in it?',
#   {'entities': [[38, 44, 'bless,']]}),
#  ('booziest weekend in a long time, good fun though!',
#   {'entities': [[33, 41, 'good fun']]}),
#  (' Ok then have a good day', {'entities': [[16, 20, 'good']]}),
#  ('says Happy Mother`s Day to all Moms out there  http://plurk.com/p/stkr2',
#   {'entities': [[5, 23, 'Happy Mother`s Day']]}),
#  ('_michele thanks for that...am now following them...love good causes',
#   {'entities': [[51, 67, 'love good causes']]}),
#  ('philosophy final today! thank you  it`s 3 days now!!!!',
#   {'entities': [[24, 33, 'thank you']]}),
#  (' lol i know but it was just so funny, ahaha',
#   {'entities': [[31, 37, 'funny,']]}),
#  (' lol hi emmy, latin would help me study for the aptitude tests to get into grad school ;\\ thats why i wanna take it',
#   {'entities': [[20, 62, 'would help me study for the aptitude tests']]}),
#  ('_kap But I think it`s cute.  Do this every night okay?',
#   {'entities': [[22, 27, 'cute.']]}),
#  ('Is happy...Skool just let out..! Today was my last day..! Yippee! R.I.P Jackson Tyler Morris..! Always Loved And Never Forgotten..!',
#   {'entities': [[103, 108, 'Loved']]}),
#  (' nice one !', {'entities': [[1, 5, 'nice']]}),
#  ('Gotta get creative with these mothers day gifts. I`m gonna win them over with my love!!',
#   {'entities': [[81, 87, 'love!!']]}),
#  (' aah. well, have a few friends over there. Just wondering if all`s great and weather`s been good...',
#   {'entities': [[92, 97, 'good.']]}),
#  ('_xo they were so pretty and took like an hour to do  CAN I DO URSSSSS!',
#   {'entities': [[4, 23, 'they were so pretty']]}),
#  (' Already got my ticket; thanks for making sure though!',
#   {'entities': [[24, 30, 'thanks']]}),
#  ('Thanks to all my new followers!', {'entities': [[0, 6, 'Thanks']]}),
#  ('busy working on a new kit... and a couple interviews done...Yea! The weekend! Pray for my Uncle, still young and had a massive stroke!!',
#   {'entities': [[78, 96, 'Pray for my Uncle,']]}),
#  ('Good Morning! - Court - Crossfit - Bible Study - Someone very special`s house  http://tinyurl.com/cjs668',
#   {'entities': [[57, 71, 'very special`s']]}),
#  (' Have a great time in London', {'entities': [[8, 13, 'great']]}),
#  ('  Thanks for the greeting', {'entities': [[2, 8, 'Thanks']]}),
#  (' http://twitpic.com/4wb52 - Such a pretty baby!',
#   {'entities': [[28, 47, 'Such a pretty baby!']]}),
#  ('jungle book 2 is sooooo cute.. i have nothing to eat or drink',
#   {'entities': [[24, 30, 'cute..']]}),
#  (' ah, ok  thank youuuuuu!', {'entities': [[6, 14, 'k  thank']]}),
#  ('no phone call yet.. 20 minutes until I pluck up the courage. I WISH MY PHONE WOULD RING',
#   {'entities': [[63, 67, 'WISH']]}),
#  (' SherriEShepherd gave the link for  http://www.brentozar.com/twitter. He gives Twitter tips. Hope this helps',
#   {'entities': [[68, 108, '. He gives Twitter tips. Hope this helps']]}),
#  (' I loved him and he was in a mini', {'entities': [[1, 12, 'I loved him']]}),
#  ('  Yeah I`m okay been icing and ace bandage and sitting on my **** on twitter... LOL Thanks',
#   {'entities': [[76, 88, '... LOL Than']]}),
#  (' you`re so gorgeous!!', {'entities': [[11, 20, 'gorgeous!']]}),
#  ('I guess the relaxing dinner and a movie is out for tonight...I was looking forward to that after my day at work',
#   {'entities': [[0,
#      111,
#      'I guess the relaxing dinner and a movie is out for tonight...I was looking forward to that after my day at work']]}),
#  (' rofl uh huh', {'entities': [[1, 12, 'rofl uh huh']]}),
#  (' This was funny! I have 7.', {'entities': [[10, 16, 'funny!']]}),
#  (' good luck!! How exciting', {'entities': [[1, 5, 'good']]}),
#  ('Working up to my vacation to Thailand. Getting more excited every day',
#   {'entities': [[52, 59, 'excited']]}),
#  ('Finally a chance to show genuine love, not dependent selfish love, I hope I can do it. My heart goes out to you and I`m sorry 4 ur pain.',
#   {'entities': [[33, 38, 'love,']]}),
#  (' the exact one i was thinking of  the bestttt.',
#   {'entities': [[36, 45, 'e bestttt']]}),
#  ('Why does #googledocs do folders, instead of labels like #gmail? I kind of like labels',
#   {'entities': [[51, 55, 'like']]}),
#  ('pacquiao fight was fun at home wif fam and melissa sat.    today was a mission to ikea. srsly 4 different freeways to ge to burbank.',
#   {'entities': [[19, 22, 'fun']]}),
#  (' How much longer is the NKOTB Block Party? Love it! I need to go to bed so just wondering what time it`s over..LOL..thanks!',
#   {'entities': [[43, 47, 'Love']]}),
#  ('Cultural tour 102 by loiusa`s family: kangaroo sight-seeing in cemetary. Lovely',
#   {'entities': [[73, 79, 'Lovely']]}),
#  ('Oh, and yippee for Lyn-Z Way who gets to celebrate Mother`s Day for the first time as a mother.',
#   {'entities': [[41, 50, 'celebrate']]}),
#  ('am chillaxin after a busy BankHoliday, Hope everbody had a gd wkend! Holiday in 12 days!!!  ****',
#   {'entities': [[0,
#      89,
#      'am chillaxin after a busy BankHoliday, Hope everbody had a gd wkend! Holiday in 12 days!!']]}),
#  ('Havin a much better day today!! Finished the last Twilight book yesterday. Classes start next week!      Get at me yall!!',
#   {'entities': [[13, 19, 'better']]}),
#  (' NEW motorcycle and you POPPED a cable already? wow-you ride HARD!',
#   {'entities': [[48, 66, 'wow-you ride HARD!']]}),
#  (' Thanks! Welcome back!', {'entities': [[1, 22, 'Thanks! Welcome back!']]}),
#  (' Thanks Amy!  That video is so awesome!  Did you see TMH?  He`s amazing in that too!! Bouncy Bouncy Bouncy!!!',
#   {'entities': [[60, 69, 'e`s amazi']]}),
#  (' LMAO...Ha! No I just simply wanted to go to NY!',
#   {'entities': [[1, 11, 'LMAO...Ha!']]}),
#  (' hahaha oh man please come to pomona i would love to see you everyday instead of like once a year if that',
#   {'entities': [[45, 49, 'love']]}),
#  ('Jon made one of the greatest dinners ever: roast pork tenderloin on a bed of wild rice on a bed of mixed greens & yummy sauce. No wine',
#   {'entities': [[9, 42, 'one of the greatest dinners ever:']]}),
#  ('Shower. Class. More class. Taking care of my lady-friend. Writing like there`s no tomorrow.',
#   {'entities': [[0,
#      57,
#      'Shower. Class. More class. Taking care of my lady-friend.']]}),
#  ('Rockstar photographer shoot went great tonight. A little different than the usual stuff - very nice.',
#   {'entities': [[33, 38, 'great']]}),
#  (' great pics! You should try to start selling your race photos to runners',
#   {'entities': [[1, 6, 'great']]}),
#  ('Goodmorning twitter, oh my gosh, i woke up soooo nice, lol ... oh hai thar twitterverse. Happy #mothersday everybody  (especially mine)',
#   {'entities': [[0,
#      116,
#      'Goodmorning twitter, oh my gosh, i woke up soooo nice, lol ... oh hai thar twitterverse. Happy #mothersday everybody']]}),
#  ('_dulay i swear it took me 2 hours to get from bel air to alabang.  but yes, i LOVED reminiscing about our HK trip with you & ',
#   {'entities': [[76, 83, 'i LOVED']]}),
#  ('The World is just amazing!',
#   {'entities': [[0, 26, 'The World is just amazing!']]}),
#  (' awww hes too cute!!wish i could`ve gone',
#   {'entities': [[14, 19, 'cute!']]}),
#  ('just had a great talk with grace about how awesome God is and how he works...that somehow started with how remote controls work',
#   {'entities': [[0,
#      127,
#      'just had a great talk with grace about how awesome God is and how he works...that somehow started with how remote controls work']]}),
#  ('HAPPY MOTHER`S DAY to my Mom, and every Mom everywhere.  Off for a stroll at the Beaches later--hopefully...',
#   {'entities': [[0,
#      108,
#      'HAPPY MOTHER`S DAY to my Mom, and every Mom everywhere.  Off for a stroll at the Beaches later--hopefully...']]}),
#  ('_KittyKat hello new follower  haha!! how are ya?',
#   {'entities': [[30, 35, 'haha!']]}),
#  (' haha best thing about office birthdays hey',
#   {'entities': [[6, 10, 'best']]}),
#  ('You better come here by the time I count to 10 or else. 1, 2, 3,  BAM!!!!!',
#   {'entities': [[0,
#      74,
#      'You better come here by the time I count to 10 or else. 1, 2, 3,  BAM!!!!!']]}),
#  ('_3 U know - kids do what we DO - not what we SAY ... well, don`t we all, really  ....',
#   {'entities': [[53, 58, 'well,']]}),
#  ('  Hi, Thx for following  I teach some Chinese lessons on youtube, pls feel free to have a look www.youtube.com/ChineseLearn',
#   {'entities': [[4, 9, ', Thx']]}),
#  ('  Yes, you should go see Star Trek!  It`s sooooo much fun!',
#   {'entities': [[51, 56, 'ch fu']]}),
#  (' very relaxing thank you. Hope you get to put your feet up tomorrow and enjoy the day',
#   {'entities': [[1, 14, 'very relaxing']]}),
#  (' yessir that is 100% right',
#   {'entities': [[1, 26, 'yessir that is 100% right']]}),
#  ('Writing my Music Lit final paper on Mozart`s Eine kleine nashtmusik. Mom is giving me a hand...and I`m actually having a GREAT time',
#   {'entities': [[121, 126, 'GREAT']]}),
#  (' aww thanx andy', {'entities': [[5, 10, 'thanx']]}),
#  ('Some goodies bagged at the car boot including some very cute cross stitch birds for my craft room! The man selling was a sweetie',
#   {'entities': [[51, 60, 'very cute']]}),
#  ('has just finished ironing his clothes for #Church. Gonna walk the dog now then grab a shower/shave and be off  #jottonia looks good too',
#   {'entities': [[127, 131, 'good']]}),
#  (' COOOOOOOOOL... DOOOOOOOOOWN... Patience... Is... Virtue...',
#   {'entities': [[1,
#      59,
#      'COOOOOOOOOL... DOOOOOOOOOWN... Patience... Is... Virtue...']]}),
#  ('The usual. Two family parties today. Happy Birthday Lily!  http://twitpic.com/4w472',
#   {'entities': [[37, 42, 'Happy']]}),
#  ('GOODNIGHT MAGIC AND PRETTY WORLD', {'entities': [[0, 9, 'GOODNIGHT']]}),
#  ('Good morning  ready to start this week.', {'entities': [[0, 4, 'Good']]}),
#  (' I`ve read good things bout it. Just not feelin it tonight. Proly finish it tomorrow, after Star Trek',
#   {'entities': [[11, 15, 'good']]}),
#  ('So glad I`m finally done with finals!', {'entities': [[3, 7, 'glad']]}),
#  (' I miss u guys too  I prob won`t b bk til august sumtime... But if I come bk anytime b4 then ill 4 sure let u kno!',
#   {'entities': [[1,
#      56,
#      'I miss u guys too  I prob won`t b bk til august sumtime']]}),
#  ('Just got confirmed that itï¿½s pizza-time with some ex co-workers on friday...looking forward to it',
#   {'entities': [[78, 99, 'looking forward to it']]}),
#  ('can`t wait to november for Jobros concert ! In examination',
#   {'entities': [[0, 43, 'can`t wait to november for Jobros concert !']]}),
#  ('i jus love doin night shifts...will be done in an hour',
#   {'entities': [[0, 31, 'i jus love doin night shifts...']]}),
#  (' You know, your updates are really amusing.  How was the prop auction?How much did that baseship bed go for?',
#   {'entities': [[11, 43, 'your updates are really amusing.']]}),
#  ('Loves the fact that there`s only 5 days of school left',
#   {'entities': [[0, 14, 'Loves the fact']]}),
#  (' Oh no!! I hope it`s not bad', {'entities': [[19, 28, 's not bad']]}),
#  (' awesome..am headin there that nite after my grad dinner  c u then boi! hehe',
#   {'entities': [[1, 9, 'awesome.']]}),
#  (' Aww, congrats to the family. ;) Send me piccies in the email!',
#   {'entities': [[1, 29, 'Aww, congrats to the family.']]}),
#  ('Uber Bored ATM, after Out of the Blue, will have shower, then watch house or numb3rs (vid) then CSI + CSI NY + Bones Double . .. . YAY!',
#   {'entities': [[131, 135, 'YAY!']]}),
#  ('okay okay sleep for realz now! Goodnight!  ::waves to followers::',
#   {'entities': [[31, 41, 'Goodnight!']]}),
#  ('__buckley Good for you mate, sadly I couldnt get pissed tonight **** driving bad times',
#   {'entities': [[10,
#      86,
#      'Good for you mate, sadly I couldnt get pissed tonight **** driving bad times']]}),
#  (' very very cute  and fun to watch.',
#   {'entities': [[1, 15, 'very very cute']]}),
#  ('Great weekend, even though my site is not moved. Plenty other things to do and learn. Keeping the faith and looking to the future',
#   {'entities': [[0, 5, 'Great']]}),
#  (' thats what doting husbands are for LOL!!  I hope that once my braces go on, I can eat normally again',
#   {'entities': [[43, 49, 'I hope']]}),
#  ('Good Morning Twits!  Let`s makes today x100 better than the one before! Start runnin',
#   {'entities': [[0, 4, 'Good']]}),
#  (' Thanks man.  That sorted it. I only ever remember 222.222',
#   {'entities': [[1, 28, 'Thanks man.  That sorted it']]}),
#  ('_Craig_G Hope your enjoying the money..it`s looking real good to me right now',
#   {'entities': [[19, 27, 'enjoying']]}),
#  ('This is my favourite shirt, because its true.  <3 grumpy.    a) cute  b) huggable  c) life of the party  (d)... http://tinyurl.com/q7eax7',
#   {'entities': [[11, 20, 'favourite']]}),
#  ('and thanks,  , fr. yr congratulatory gweetin`',
#   {'entities': [[22, 36, 'congratulatory']]}),
#  ('Star trek was good times.', {'entities': [[14, 25, 'good times.']]}),
#  ('Invisible car helps to boost recycling. Honest   http://twurl.nl/fdgmyo',
#   {'entities': [[0, 46, 'Invisible car helps to boost recycling. Honest']]}),
#  ('HA. Totally posting an update at 2am.Its lightning outside, pretty.',
#   {'entities': [[60, 67, 'pretty.']]}),
#  (' Do a tour in the Philippines sometime.  A lot of fans here would really love that!',
#   {'entities': [[64, 83, 'd really love that!']]}),
#  (' nice clutch', {'entities': [[1, 5, 'nice']]}),
#  ('Happy Mother`s Day to all the mommies', {'entities': [[0, 5, 'Happy']]}),
#  ('Enjoying Mother`s Day', {'entities': [[0, 8, 'Enjoying']]}),
#  ('Wishing all the mommies out there a very happy day!!!',
#   {'entities': [[41, 46, 'happy']]}),
#  (' ahaha its stuck in my head; thanxx', {'entities': [[29, 35, 'thanxx']]}),
#  ("Happy Star Wars Day ...  'May the 4th be with you'.... read http://tinyurl.com/axsujx for more ;)",
#   {'entities': [[0, 8, 'Happy St']]}),
#  ('I hope everyone had a great weekend! I will be here on and off today as I have 2 important meetings today',
#   {'entities': [[2, 6, 'hope']]}),
#  (' http://twitpic.com/4qpzx - i love you guys  you`re the best',
#   {'entities': [[42, 60, 's  you`re the best']]}),
#  ('_babe woo! im getting mine on monday,cant wait  x',
#   {'entities': [[37, 46, 'cant wait']]}),
#  (' awww she`s laavly ;) I had to come in  but I`ve got a stunning wee tan (l) ;) yourself?',
#   {'entities': [[12, 18, 'laavly']]}),
#  (' well if i use all my tweets will be the push to make me go to the shop. and by the time im back it will be over hopefully',
#   {'entities': [[113, 122, 'hopefully']]}),
#  ('is getting ready for bed. Happy Mother`s Day to all the mothers out there!',
#   {'entities': [[26, 31, 'Happy']]}),
#  (' (blinks fast) its better now ... Lol thanks :-*',
#   {'entities': [[38, 44, 'thanks']]}),
#  (' (cont) a bastardized version of French? It`s fun, believe me!',
#   {'entities': [[44, 50, 's fun,']]}),
#  (' alas, I am moving   (like where i`m moving too, but the actual moving, ugh) wish I could go too!',
#   {'entities': [[74, 96, 'h) wish I could go too']]}),
#  ('today Jon Doe plays at the Moho. ia m excited  itï¿½s gonna be funny.. but before i have to carry all the equipment and do the backline',
#   {'entities': [[38, 45, 'excited']]}),
#  (' congradts on ur show  Even tho i wasnt there lol',
#   {'entities': [[1, 49, 'congradts on ur show  Even tho i wasnt there lol']]}),
#  ('damjust finished watching Prison Break: the final break...omg i dont think i`ve cried so hard for a show..Finally understand the finale',
#   {'entities': [[0,
#      135,
#      'damjust finished watching Prison Break: the final break...omg i dont think i`ve cried so hard for a show..Finally understand the finale']]}),
#  (' good luck.. Finally your long time will of panvel tweetup finally coming true..',
#   {'entities': [[1, 5, 'good']]}),
#  ('Heading off to Hollywood Studios today  Manta and Kraken were both awesome yesterday, feeling like doing a few more rides!!',
#   {'entities': [[67, 74, 'awesome']]}),
#  (' Welcome', {'entities': [[1, 8, 'Welcome']]}),
#  (' Ha! Thanks Bryan! And don`t remind me about the state budget issues.  Actually, Steve only has 6 staffers in 3 offices.',
#   {'entities': [[5, 11, 'Thanks']]}),
#  (' Thanks, none close to me.', {'entities': [[1, 8, 'Thanks,']]}),
#  ('watered the tomato plants, pepper plants and lettuce, feeling all homely! off out with Freddie for a fun-packed day',
#   {'entities': [[54,
#      115,
#      'feeling all homely! off out with Freddie for a fun-packed day']]}),
#  (' I sorry', {'entities': [[1, 8, 'I sorry']]}),
#  (' if so, the TMobile G1 is the Hummer H1. I wish I had the battery life of an iPhone!',
#   {'entities': [[41, 84, 'I wish I had the battery life of an iPhone!']]}),
#  ('nite nite twitts i wish u all a happy sunday i already have my major gift my my 2kids-my bro-n @_agressiva23 n 1 other gift on d way  tyg',
#   {'entities': [[32, 37, 'happy']]}),
#  ('Omg. Its 1:47 am and Kim Possible is on Disney Channel right now. I am glued to the screen',
#   {'entities': [[0, 4, 'Omg.']]}),
#  (' at first i thought bar life meant you were partying nonstop to catch up for the last 2 years...lol shoulda known better',
#   {'entities': [[114, 120, 'better']]}),
#  (' someone came in when I was sleeping off my national passtime and turned me human',
#   {'entities': [[64, 81, 'd turned me human']]}),
#  (' I see you didn`t shave your head. But I *LOVE* the cut.  I`m glad you didn`t shave it. Your hair`s too pretty!',
#   {'entities': [[60, 66, 'm glad']]}),
#  (' I am twittering, LIKE A BOSS. Thanks Savvv',
#   {'entities': [[31, 43, 'Thanks Savvv']]}),
#  (' my sleep pattern is screwed i need to try and stay up 2 midnight so i can get some decent sleep coz i havent slept',
#   {'entities': [[1, 28, 'my sleep pattern is screwed']]}),
#  ('may the fourth be with you! happy star wars day',
#   {'entities': [[0, 47, 'may the fourth be with you! happy star wars day']]}),
#  ('Always thinking about to look for a good place to appericiate everyone who supports me on every site I joined',
#   {'entities': [[36, 40, 'good']]}),
#  ('can`t believe I just drove all the way back to school...whatever HAPPY MOTHER`S DAY: Mommy, Precious, Candis and Granny',
#   {'entities': [[65, 70, 'HAPPY']]}),
#  ('i hope it doesnt rain tonight tomorrow my fam. comes to visit swimming pool and carne asada  if it rains the pool is going to be dirty',
#   {'entities': [[0, 6, 'i hope']]}),
#  (' That`s me on a good day',
#   {'entities': [[1, 24, 'That`s me on a good day']]}),
#  (' I created my account just to get a chance to chat with you (: I ADMIRE YOU! you`re amazing! you inspire me to write  <3',
#   {'entities': [[61,
#      120,
#      ': I ADMIRE YOU! you`re amazing! you inspire me to write  <3']]}),
#  ('Think I`ll go enjoy the sun`s rays again...I LOVE being off work',
#   {'entities': [[43, 64, 'I LOVE being off work']]}),
#  (' hahaha, I was busy, now I see what I replied to you! Yes that is true',
#   {'entities': [[1,
#      53,
#      'hahaha, I was busy, now I see what I replied to you!']]}),
#  (' thank you cici  right back at ya!', {'entities': [[1, 10, 'thank you']]}),
#  (' Thank you  x', {'entities': [[1, 10, 'Thank you']]}),
#  (' I think we have it pretty much figured out.  added a box in the Helsinki group where you can see the tweets',
#   {'entities': [[20, 44, 'pretty much figured out.']]}),
#  (' http://twitpic.com/4vdc3 - Lexus has the Twitpic! Happy mother`s day to you Lexus.  I hopw it`s a nice one for you.',
#   {'entities': [[51,
#      116,
#      'Happy mother`s day to you Lexus.  I hopw it`s a nice one for you.']]}),
#  ('_uts bass love', {'entities': [[10, 14, 'love']]}),
#  ('omg J.O.N.A.S. is my new fave show <3 one guess as to why hahahha',
#   {'entities': [[25, 29, 'fave']]}),
#  (' Yeah it is. Thanks', {'entities': [[13, 19, 'Thanks']]}),
#  (' Congrats on the knottie man!', {'entities': [[1, 9, 'Congrats']]}),
#  (' there coming this year ^-^  wiL said it himself  but yes now would be good.',
#   {'entities': [[51, 75, 'ut yes now would be good']]}),
#  (' awww  I`ll let you off - but you`d better be there for my next 30th! XD',
#   {'entities': [[1,
#      72,
#      'awww  I`ll let you off - but you`d better be there for my next 30th! XD']]}),
#  ('i think i just good stood up...', {'entities': [[15, 19, 'good']]}),
#  ('hook up with Rian van Staden on Twitter. He is a (much) better cook and may have some more concrete suggestions',
#   {'entities': [[49, 67, '(much) better cook']]}),
#  (' Nako! Umuulan pa naman!  Anyway, enjoy the bike rides!',
#   {'entities': [[32, 39, ', enjoy']]}),
#  ('has just discovered a great site!', {'entities': [[22, 27, 'great']]}),
#  (' Oohh Yaay like it !  ?    Love ya',
#   {'entities': [[6, 31, 'Yaay like it !  ?    Love']]}),
#  ('_Lhoste Thanks you so much for following me on Twitter; I hope you find it as exciting as I do! Looking forward to your tweets!',
#   {'entities': [[8, 26, 'Thanks you so much']]}),
#  ('Happy Mother`s Day to all the mommies out there, be you woman or man as long as you`re `momma` to someone this is your day!',
#   {'entities': [[0, 18, 'Happy Mother`s Day']]}),
#  (' Hi I have uploaded 5 completely new Chinese Lessons on www.youtube.com/ChineseLearn Please feel free to watch and enjoy',
#   {'entities': [[85, 120, 'Please feel free to watch and enjoy']]}),
#  (' That was nice. I Just ordered my mom her gift from me and my sister.   Something different and unexpected.',
#   {'entities': [[10, 15, 'nice.']]}),
#  ('Don`t follow your dreams; chase them.- Richard Dumb (who I think is very smart',
#   {'entities': [[53, 78, 'who I think is very smart']]}),
#  (' Up is out?  I didn`t get the memo   It looks amazing.',
#   {'entities': [[33, 51, 'o   It looks amazi']]}),
#  (' yeah twitter is a lot of fun babe... especially when you`ve got ppl to talk to! lol & that sounds Goooooood lol',
#   {'entities': [[1,
#      112,
#      'yeah twitter is a lot of fun babe... especially when you`ve got ppl to talk to! lol & that sounds Goooooood lol']]}),
#  ('tonight was hilariouss  i loveeee everyone that was theree',
#   {'entities': [[26, 33, 'loveeee']]}),
#  (' thank YOU!! You guys did awesome things for my blog tonight  so grateful!!',
#   {'entities': [[62, 75, 'so grateful!!']]}),
#  ('@_TWEE haha thanks to you that`s my new word for the week! ****',
#   {'entities': [[12, 28, 'thanks to you th']]}),
#  ('Happy Mom`s day to your moms !', {'entities': [[0, 5, 'Happy']]}),
#  ('_Guy Would luv to hear music too but iï¿½m out of batteries - the tv plays besides but i think this is some kind of vampire movie',
#   {'entities': [[11, 14, 'luv']]}),
#  ('Just wanted to say, positivity is doin me good! Change it up! Won`t regret it... Forsure..',
#   {'entities': [[20,
#      90,
#      'positivity is doin me good! Change it up! Won`t regret it... Forsure..']]}),
#  (' I had mint ice-cream for dessert tonight. Love the stuff!',
#   {'entities': [[43, 47, 'Love']]}),
#  ('watching snl with my ucsd girls and laughing about twitter/blackberry jokes  thought i`d tweet that.',
#   {'entities': [[36, 44, 'laughing']]}),
#  (' i think both ?s related to size depend on structures and system: hard to relay in tweet but worth blogging..good questions this am',
#   {'entities': [[93, 98, 'worth']]}),
#  ('Is having awesome fruits and vegetable juice at the opening of Lam`s noodles at 8  http://tinyurl.com/r65c68',
#   {'entities': [[10, 17, 'awesome']]}),
#  ('Packing up and leaving inlaws house heading home sweet home... Had a nice weekend and back to work in a few hours',
#   {'entities': [[69, 76, 'nice we']]}),
#  ('HAPPY MOMMA`s DAY ALL. HONOR YOUR MOMs  sign up for #maternalhealth  here`s for all mothers and luvin kids out there:  http://bit.ly/Bpekk',
#   {'entities': [[0, 22, 'HAPPY MOMMA`s DAY ALL.']]}),
#  ('y do i only have 2 people following me  people follow me please x',
#   {'entities': [[57, 63, 'please']]}),
#  ('Aw. Toy Story 3 is coming out NEXT year.',
#   {'entities': [[0, 40, 'Aw. Toy Story 3 is coming out NEXT year.']]}),
#  ('goooodnight everyone!  and Happy Mothers Day to all the mothers out there.',
#   {'entities': [[27, 32, 'Happy']]}),
#  ('My whole immediate will be in the same city until some point tomorrow afternoon. This is monumental',
#   {'entities': [[89, 99, 'monumental']]}),
#  ('Good days with good friends make me not regret living',
#   {'entities': [[0, 30, 'Good days with good friends ma']]}),
#  ('OMG I would sooooo make dis show number one n da ratings',
#   {'entities': [[0, 43, 'OMG I would sooooo make dis show number one']]}),
#  (" Yes...met Jon last yr at an interesting 'Questionning Agile' Agile 2008 session.  Don`t see him on this yr`s schedule.",
#   {'entities': [[27, 40, 'n interesting']]}),
#  (' aaawww  no worries fresh start to work on growing it out again',
#   {'entities': [[1, 19, 'aaawww  no worries']]}),
#  ('Just spent the last two hours playing L4D with babe  Had HELLA fun. I love him <3',
#   {'entities': [[63, 67, 'fun.']]}),
#  (' nice to have you back', {'entities': [[1, 22, 'nice to have you back']]}),
#  (' Enjoy the coffee. We miss you, petite puce (adica Puricel in franceza)',
#   {'entities': [[1, 18, 'Enjoy the coffee.']]}),
#  (' my little felted thing looks like an incestuous by- product of two of your lovelies',
#   {'entities': [[1,
#      84,
#      'my little felted thing looks like an incestuous by- product of two of your lovelies']]}),
# ...
#  (' I think that boat sailed my friend... The few CCO`s that had them, had them months ago....  I wish you luck though...',
#   {'entities': [[93, 118, 'I wish you luck though...']]}),
#  ('awwww bless her  she needs another chance.',
#   {'entities': [[0, 15, 'awwww bless her']]}),
#  ('We are in the State of Cheese - YUM! Green, moo-cow pastures everywhere, and super friendly Lutheran`s too',
#   {'entities': [[32, 36, 'YUM!']]}),
#  ('bye bye for now you lovely tweeters and especially my followers',
#   {'entities': [[20, 35, 'lovely tweeters']]}),
#  ('i won because im awesome', {'entities': [[17, 24, 'awesome']]}),
#  (' Problems seem to be fixed now! Thank you!',
#   {'entities': [[32, 42, 'Thank you!']]}),
#  ('Happy Mothers Day to all the mommy`s out there!',
#   {'entities': [[0, 47, 'Happy Mothers Day to all the mommy`s out there!']]}),
#  (' haha i love both of them too  hmm.. lol i`m in need of some good bands too',
#   {'entities': [[1, 25, 'haha i love both of them']]}),
#  ('Happy Birthday Mommy', {'entities': [[0, 5, 'Happy']]}),
#  (' You are too kind! I swear I`m always feeding someone!',
#   {'entities': [[1, 18, 'You are too kind!']]}),
#  (' good tip..... but then my boss would read .... exactly what im supposed to do and would know where I was with the project',
#   {'entities': [[1, 10, 'good tip.']]}),
#  (' Star Trek is really good. I loved it too',
#   {'entities': [[29, 34, 'loved']]}),
#  ('finally gonna get sum sleep  that concert was crazy!!! God Bless those ministers!!!',
#   {'entities': [[55, 64, 'God Bless']]}),
#  ('school..  i wish it would just end already!',
#   {'entities': [[12, 16, 'wish']]}),
#  ('Happy Mothers Day. Havent got mom a present yet? Print off an Amazon Gift Card for her!  http://snipurl.com/hq0n1',
#   {'entities': [[0, 5, 'Happy']]}),
#  (' thanks for your follow  just do you own thing + join in with what interests you',
#   {'entities': [[1, 23, 'thanks for your follow']]}),
#  (' aw honey... you just relaxin? That`s probably for the best.',
#   {'entities': [[1, 10, 'aw honey.']]}),
#  (' coooooooool, yes, CIWWAF are awesome.',
#   {'entities': [[30, 38, 'awesome.']]}),
#  ('Control which tweets u post on Facebook by using a hashtag, check out this awesome easy app!  http://apps.facebook.com/selectivetwitter/',
#   {'entities': [[75, 82, 'awesome']]}),
#  ('I am chillin w/ my homies', {'entities': [[5, 12, 'chillin']]}),
#  (' I`m glad you liked it   Want more?', {'entities': [[5, 9, 'glad']]}),
#  ("just watched that  new T-mobile advert on Youtube.. i love it  'hey jude!!!!!!'",
#   {'entities': [[54, 58, 'love']]}),
#  ('Morning world. Hello Bank Holiday! Cold and grey and rainy here. Feel like colouring thanks to  so might do that this am',
#   {'entities': [[85, 91, 'thanks']]}),
#  ('I am soo happy! Thank you baby for the best 1095 days of my life',
#   {'entities': [[0, 15, 'I am soo happy!']]}),
#  (' Not a problem at all sis - respect due',
#   {'entities': [[1, 14, 'Not a problem']]}),
#  ('   Sure!  My entire blogroll is terribly updated, but this could motivate me to update and redo it!',
#   {'entities': [[61, 71, 'uld motiva']]}),
#  ('_anstee i hope! its in expo! that would be amazing. im trying so hard to make perfection so it is.',
#   {'entities': [[78, 88, 'perfection']]}),
#  (' nm. dang, you on NOW but i gotta bounce in like 4 minutes  i`m just chilling. the usual.',
#   {'entities': [[60, 77, 'i`m just chilling']]}),
#  ('_Reviews THANKS!', {'entities': [[9, 16, 'THANKS!']]}),
#  (' Going so soon? I was hoping to hear late nite humor from you....',
#   {'entities': [[22, 28, 'hoping']]}),
#  (' It is absolutely incredible. It`s official: My FAVORITE JONAS is FRANKIE. He is the man',
#   {'entities': [[18, 29, 'incredible.']]}),
#  ('Happy Birthday to my ****',
#   {'entities': [[0, 25, 'Happy Birthday to my ****']]}),
#  (' Can you please  with that? I`d love some egg +bacon +ranch +bed for giving birth 3 times in 4 years!',
#   {'entities': [[25, 36, 't? I`d love']]}),
#  ('   ...Thank you Mr. President!....',
#   {'entities': [[3, 31, '...Thank you Mr. President!.']]}),
#  (' Ooo showing of your French skills!! lol Things good over here. Lovely weather, so should be outside  How`s u?',
#   {'entities': [[41, 79, 'Things good over here. Lovely weather,']]}),
#  ('The Star Trek movie was amazing! omg everyone has to go see it',
#   {'entities': [[24, 32, 'amazing!']]}),
#  (' happy birthday', {'entities': [[1, 6, 'happy']]}),
#  ('I`m entering a two month study/exam period.  Which is awesome. - See you on the flip side',
#   {'entities': [[45, 62, 'Which is awesome.']]}),
#  (' it`s best if i check it while it IS up. when it`s down, i can`t really see anything',
#   {'entities': [[6, 10, 'best']]}),
#  ('Lil cuz coming round today she 5  aww  haha',
#   {'entities': [[39, 43, 'haha']]}),
#  ('Goodmorning twitter bugs.. happy monday to you all! Today marks my first official day at my first fulltime job.. time to get ready!',
#   {'entities': [[27, 32, 'happy']]}),
#  (' braving the standby line @ TheView bright & early today!! hope to hear about your book & hope I get in! 3rd time`s the charm',
#   {'entities': [[59, 63, 'hope']]}),
#  (' Good Luck', {'entities': [[1, 5, 'Good']]}),
#  ('Apple is expected to launch a new iPhone this summer.  Hi my name is Judy and I am addicted to Apple products.',
#   {'entities': [[9, 17, 'expected']]}),
#  ('Clambering about in crashed cars. Hilarious fun',
#   {'entities': [[34, 43, 'Hilarious']]}),
#  ('http://tr.im/kXCL `Immigrant hid passport in pants` What a genius.',
#   {'entities': [[52, 66, 'What a genius.']]}),
#  (' LOL good to know the time in LA, it`s a 9h time difference ...  good morning to ya',
#   {'entities': [[5, 17, 'good to know']]}),
#  (' lol awww lol i will i can`t do it now lol cauz i have to work  but i will make one and tell you love you 2 oxoxoteambreezy',
#   {'entities': [[86, 123, 'd tell you love you 2 oxoxoteambreezy']]}),
#  (' Soooo happy your back!',
#   {'entities': [[1, 23, 'Soooo happy your back!']]}),
#  (' U no that little prob with ur twitter that happen @ that old pep resteraunt! mayb this will help u fix it',
#   {'entities': [[78, 106, 'mayb this will help u fix it']]}),
#  (' Because pop culture is beautiful. Also, you can`t pull weeds wrong. I promise. You can practice on my yard if you are nervous',
#   {'entities': [[1,
#      126,
#      'Because pop culture is beautiful. Also, you can`t pull weeds wrong. I promise. You can practice on my yard if you are nervous']]}),
#  ('Wishing all MOMs a very Happy Mother`s Day!!',
#   {'entities': [[17, 44, 'a very Happy Mother`s Day!!']]}),
#  ('great party alenka!!  happy birthday chicky! <3',
#   {'entities': [[0, 44, 'great party alenka!!  happy birthday chicky!']]}),
#  (' lol. I see what you did there.', {'entities': [[1, 5, 'lol.']]}),
#  (' heh coincidence im a barnsley fan too  how`d you track me down :o',
#   {'entities': [[31, 38, 'fan too']]}),
#  ('Just got my heart ripped out  i love you guys',
#   {'entities': [[0, 45, 'Just got my heart ripped out  i love you guys']]}),
#  (' Thanks for the song! Youï¿½re awesome.  I can sing along all day!',
#   {'entities': [[1, 39, 'Thanks for the song! Youï¿½re awesome.']]}),
#  (' was jus so excited t c ur name', {'entities': [[12, 19, 'excited']]}),
#  ('good morning tweetie world.  have a great day, everyone.',
#   {'entities': [[0, 4, 'good']]}),
#  (' Philly hasn`t played it yet!!!  You have to do something about that!! Please',
#   {'entities': [[69, 77, '! Please']]}),
#  (' yeah, getting shows can be an interesting process.  the key is following up... at least that`s what i`ve learned so far',
#   {'entities': [[7, 51, 'getting shows can be an interesting process.']]}),
#  ('_luca LOL!  I`m glad to see I`m not the only one out there!!!',
#   {'entities': [[12, 27, 'I`m glad to see']]}),
#  (' TAYLOR! are you back in Nashville now..or LA? well, how was your trip? did ya have fun? love ya girly!',
#   {'entities': [[70, 103, '? did ya have fun? love ya girly!']]}),
#  ('Oh snap... kinda nuts right now... :  I`ve told at least 27  Thanks babes.',
#   {'entities': [[61, 67, 'Thanks']]}),
#  (' i love cobra starship!!  thanks for the suggestion!',
#   {'entities': [[1,
#      52,
#      'i love cobra starship!!  thanks for the suggestion!']]}),
#  (' I agree, keep it in Star Trek but make it commercially viable! C`mon!',
#   {'entities': [[1,
#      70,
#      'I agree, keep it in Star Trek but make it commercially viable! C`mon!']]}),
#  (' My cats enjoy the sunbeams from the open windows.  I think that counts.',
#   {'entities': [[9, 14, 'enjoy']]}),
#  ('Had a great weekend with One, hanging with Nick & Brendon, church this morning! Can`t believe Loretta won the Mothers Day raffle again!',
#   {'entities': [[6, 11, 'great']]}),
#  ("Is watching 'It takes Two'.... such a classic lol",
#   {'entities': [[31, 45, 'such a classic']]}),
#  (' Pics? Ah, I`ll probably see you at work at some point... Hopefully b4 it grows out too much',
#   {'entities': [[58, 67, 'Hopefully']]}),
#  (' I did for years and then moved over to an IBM compatible.  Would love to have both on my desk!   Can you call me a techie?',
#   {'entities': [[60, 73, 'Would love to']]}),
#  ('Happy Star Wars Day! May the 4th be with you  (via Nige the Goth)',
#   {'entities': [[0, 44, 'Happy Star Wars Day! May the 4th be with you']]}),
#  (' Thank you', {'entities': [[1, 10, 'Thank you']]}),
#  ('Laying with lyndi on drive way. Drinking tea. Listenin to music. Takin pictures. Just a Chillin.',
#   {'entities': [[81, 96, 'Just a Chillin.']]}),
#  ('i`m celebrating my mother!!  and also celebrating my legacy as a woman of God.',
#   {'entities': [[4, 15, 'celebrating']]}),
#  ('Had a gr8 Sunday relaxing enjoying the beautiful weather. Good nite',
#   {'entities': [[39, 57, 'beautiful weather.']]}),
#  (' woop rehearsing songs  Yep, sounds even enough to me',
#   {'entities': [[27, 53, ', sounds even enough to me']]}),
#  (' that would be great!!!  thanks!!',
#   {'entities': [[1, 23, 'that would be great!!!']]}),
#  ('_benson  Woohoo! Well Done! I started Macarena-ing too',
#   {'entities': [[9, 27, 'Woohoo! Well Done!']]}),
#  ('Chillaxing in Hyde park', {'entities': [[0, 10, 'Chillaxing']]}),
#  (' Whoo hoo Chuck! Although it is gloomy out, today is a much better day!',
#   {'entities': [[60, 66, 'better']]}),
#  ('Sitting waiting for dough to rise. There`s something about it that calms me down. Maybe the knowledge that I`ll have cinnamon rolls soon',
#   {'entities': [[67, 81, 'calms me down.']]}),
#  (' Made so many new friends on Twitter around USA. Another bike across USA trip would be amazing to see people!',
#   {'entities': [[78, 94, 'would be amazing']]}),
#  (' Btw happy mom`s day to hannah and your mom and han`s mom! Yey! Moms unite! This is your day',
#   {'entities': [[5, 10, 'happy']]}),
#  ('Finally a Black Disney princess.', {'entities': [[0, 7, 'Finally']]}),
#  ('wish I could feel no pain (8)  but it`s ok, at least they like Brazil!',
#   {'entities': [[58, 62, 'like']]}),
#  ('hoping i didn`t fail english. that would just be sad',
#   {'entities': [[0,
#      52,
#      'hoping i didn`t fail english. that would just be sad']]}),
#  ('A singing girl. Talented, yeah. Good to complain about? No',
#   {'entities': [[16, 25, 'Talented,']]}),
#  ('  sounds like a challenge then  I can see it would be useful to be able explicitly  schedule threads...',
#   {'entities': [[51, 59, 'be usefu']]}),
#  ('Thanks to all who follow me  ... wish ya`ll the best ;)',
#   {'entities': [[0,
#      55,
#      'Thanks to all who follow me  ... wish ya`ll the best ;)']]}),
#  ('   Thank you soooo much!!!      Bella',
#   {'entities': [[3, 12, 'Thank you']]}),
#  ('Good mornin` everyone . Beautiful sunday for all the beautiful moms of ours. Had my breakfast with the lady ....   Lets move on .',
#   {'entities': [[24, 33, 'Beautiful']]}),
#  (' yum, yum.  I love quesadillas....and wallpaper for that matter tooo',
#   {'entities': [[1, 10, 'yum, yum.']]}),
#  (' Awhhh age doesn`t matter, you awesome lady you!',
#   {'entities': [[27, 48, 'you awesome lady you!']]}),
#  (' Haha, true  thankfully the regular keyboard does the job... most of the time.',
#   {'entities': [[13, 23, 'thankfully']]}),
#  ('Had a fun late night talk with   Good night world.',
#   {'entities': [[6, 9, 'fun']]}),
#  ('may gray, coldplay, and nice showers...work at 2',
#   {'entities': [[24, 39, 'nice showers...']]}),
#  ('its funny you said we`d never make it and look how far we`ve come....  IM BACK ON HEAHHH!  um. yeah. school :/',
#   {'entities': [[4, 9, 'funny']]}),
#  (' me toooooo! Thank u', {'entities': [[13, 20, 'Thank u']]}),
#  ('. I want all the soldiers to come home so we don`t have to hear about anymore being killed.',
#   {'entities': [[0,
#      91,
#      '. I want all the soldiers to come home so we don`t have to hear about anymore being killed.']]}),
#  ('good weekend', {'entities': [[0, 12, 'good weekend']]}),
#  ('meeting  and friend tonight - going to discuss human trafficking issues. Daly is chaplain/therapist and an interesting guy',
#   {'entities': [[104, 122, 'an interesting guy']]}),
#  (' hes definitely my fav host ever!  Can`t wait to watch the rest tomorrow!!',
#   {'entities': [[16, 33, 'my fav host ever!']]}),
#  ('Happy star wars day everyone',
#   {'entities': [[0, 28, 'Happy star wars day everyone']]}),
#  (' You`re welcome. I`m going to repost several times to get the message out, maybe help another dog',
#   {'entities': [[8, 16, 'welcome.']]}),
#  ('  Enjoy...wish I was there! Nice day in Springfield today..however I have my end of month expense report to do',
#   {'entities': [[2,
#      57,
#      'Enjoy...wish I was there! Nice day in Springfield today']]}),
#  (' haha that was good, slightly geeky but funny  x',
#   {'entities': [[15, 20, 'good,']]}),
#  ('Oh, I`ve just watched the third episode of JONAS, it`s awesome.',
#   {'entities': [[50, 63, 'it`s awesome.']]}),
#  (' i love Paramore!  welcome back', {'entities': [[3, 7, 'love']]}),
#  ('_DAHSAR Thanxs hun, you too!', {'entities': [[8, 14, 'Thanxs']]}),
#  (' Fun to read, thanks! You Brits make things interesting  Funny they whittled 33 saints days to four,... http://ff.im/-2zgfk',
#   {'entities': [[57, 62, 'Funny']]}),
#  ('Just got finished cleaning and putting out my mom`s presents.  Happy mother`s day. I`m going to sleeeeep.',
#   {'entities': [[63, 68, 'Happy']]}),
#  (' thanks  i have to finish schoolwork today, no rehearsal tonight though. what ru doing?',
#   {'entities': [[1, 7, 'thanks']]}),
#  (' This is truly enlightening for me',
#   {'entities': [[7, 27, 's truly enlightening']]}),
#  (' thanks, I deserve it.', {'entities': [[1, 8, 'thanks,']]}),
#  ('  he should be an honourary fluffette, such lovely hair (what`s left  )',
#   {'entities': [[42, 50, 'h lovely']]}),
#  (' hope you had a FAB time!!! Just saw your twitpics ... Love that you wore THE dress. Great pic of D too',
#   {'entities': [[1, 5, 'hope']]}),
#  (' Cool Guide.. My best Tip.. Do NOT Use Them Unless Absolutely Needed !!!',
#   {'entities': [[14, 26, 'My best Tip.']]}),
#  ('My best friend is coming!excited', {'entities': [[25, 32, 'excited']]}),
#  (' Thought you might be interested in  http://tweetphoto.com. See who`s viewing your photos!',
#   {'entities': [[22, 32, 'interested']]}),
#  ('Sitting with sabbeth in first period.  buhahaha we are so cool -sabbeth lmao',
#   {'entities': [[58, 62, 'cool']]}),
#  ('Chicago rocks my socks', {'entities': [[8, 22, 'rocks my socks']]}),
#  (' What you said about aj made no sense,hahaha. What were you talking about? And I loved that picture of you and colin!',
#   {'entities': [[81, 86, 'loved']]}),
#  ('@_catchfire Happy Birthday Chip`s sister',
#   {'entities': [[12, 40, 'Happy Birthday Chip`s sister']]}),
#  ('whew finally got in to RC..',
#   {'entities': [[0, 27, 'whew finally got in to RC..']]}),
#  ('just tried talking........voice died before end of sentence! Annpyimg thing id, i feel fine!! Another day of not playing the hits',
#   {'entities': [[80, 96, 'i feel fine!! An']]}),
#  (' http://twitpic.com/4jam0 - better lighting would have enhanced the photo... nice angle though...',
#   {'entities': [[77, 97, 'nice angle though...']]}),
#  ('May the 4th be with you. Happy Star Wars Day!  http://ow.ly/52Aw',
#   {'entities': [[25, 40, 'Happy Star Wars']]}),
#  ...]

# %%
train(train_data, model_path, n_iter=2, model=None)
# Out:
# Created blank 'en' model
#   0%|                                                                                                                                                                            | 0/2 [00:00<?, ?it/s]
# Texts: ('Soon my new job starts  I`m so happy!', 'i`m going to try to get some sleeeeeeep. goonight twitter  have a nice mother`s day.', 'Zzzz... I`m taking my mom out for breakfast tomorrow!  Shall be quite a treat.', ' at first i thought bar life meant you were partying nonstop to catch up for the last 2 years...lol shoulda known better')
# Annotations: ({'entities': [[24, 37, 'I`m so happy!']]}, {'entities': [[59, 84, 'have a nice mother`s day.']]}, {'entities': [[55, 78, 'Shall be quite a treat.']]}, {'entities': [[114, 120, 'better']]})
# Texts: (' Well it`s nice to `see` you. Have a great day and tweet again soon', '_MEXICO Hey hey. No problem.', ' Wish I could be there to enjoy a girls day!!!', 'listening to  after last nights Up from the Underground screening, awesome job ')
# Annotations: ({'entities': [[1, 67, 'Well it`s nice to `see` you. Have a great day and tweet again soon']]}, {'entities': [[17, 28, 'No problem.']]}, {'entities': [[26, 31, 'enjoy']]}, {'entities': [[67, 74, 'awesome']]})
# Texts: (' thank`s ... See? now I`m back on smiling', '_Melbourne Sounds good! Say hi if you run into me there! I`m always always having coffee there', '_2008 don`t be sorry  you can race for charity or just for fun. I do this one for fun.', ' Stress-free is the way to be')
# Annotations: ({'entities': [[1, 7, 'thank`']]}, {'entities': [[18, 23, 'good!']]}, {'entities': [[64, 86, 'I do this one for fun.']]}, {'entities': [[1, 29, 'Stress-free is the way to be']]})
# Texts: ('trying to NOT fall asleep while doing ancient assignment. Drinking some water with ice and lime! yum', ' so glad, I hope yall make it back down near New Orleans', ' ...Now I`m going back to bed. LOL. Enjoy your time at the gym. I`ll be sleeping.', 'mint choc ice cream whilst studying.....now thats good')
# Annotations: ({'entities': [[97, 100, 'yum']]}, {'entities': [[12, 16, 'hope']]}, {'entities': [[36, 41, 'Enjoy']]}, {'entities': [[44, 54, 'thats good']]})
# Texts: ('A salute to Chapel Hill North Carolina. From SY  * ? http://blip.fm/~5jgj3', ' My pleasure. I can`t be with my mom on Mother`s Day. But I can spread love.', ' thanks  ****', 'Wohoo! Going to see Eddie Izzard in December!')
# Annotations: ({'entities': [[2, 8, 'salute']]}, {'entities': [[1, 76, 'My pleasure. I can`t be with my mom on Mother`s Day. But I can spread love.']]}, {'entities': [[1, 7, 'thanks']]}, {'entities': [[0, 6, 'Wohoo!']]})
# Texts: (' Nice! You should submit that to failblog.org', 'waking up at 6 am? yuuup. still going out tonight? you better believe it.', 'Im so full. Subway was bomb! Waiting for my 2nd shift to start', 'Gudluck to   !!')
# Annotations: ({'entities': [[1, 6, 'Nice!']]}, {'entities': [[62, 69, 'believe']]}, {'entities': [[12, 28, 'Subway was bomb!']]}, {'entities': [[0, 7, 'Gudluck']]})
# Texts: (' Yes, people skills and social manners are quite nice.  If you a few billion, guess you need MORE love to gently guide you.', ' Makes sense, I`d totally show off a girlfriend by asking her to wear her high school prom dress', ' Had lunch at Bittercreek, they were out of Hopnoxious  Had Sweetgrass IPA tho, so all is still right in the world.', ' amazing tonight glad I could share it with you baby. You are my sunshine')
# Annotations: ({'entities': [[49, 54, 'nice.']]}, {'entities': [[1, 13, 'Makes sense,']]}, {'entities': [[77, 115, 'o, so all is still right in the world.']]}, {'entities': [[1, 8, 'amazing']]})
# Texts: ('Haha. It`s pretty good  they`re making something with chicken  yum!', ' Her new cd is lovely.', 'I love my hair blowin in the wind', ' ahhh yay! I`m getting into it. Knockin` a lot out.')
# Annotations: ({'entities': [[18, 22, 'good']]}, {'entities': [[15, 22, 'lovely.']]}, {'entities': [[0, 33, 'I love my hair blowin in the wind']]}, {'entities': [[1, 10, 'ahhh yay!']]})
# Texts: ('long weekend. thank god i can sleep in on monday', 'good morning people !! in good old germany is it soooo cold', ' I do too!! Sounds interesting', " thank you  btw, if u`re wondering, you can check out the 'Fuel' brand here (  )")
# Annotations: ({'entities': [[14, 19, 'thank']]}, {'entities': [[0, 4, 'good']]}, {'entities': [[19, 30, 'interesting']]}, {'entities': [[1, 10, 'thank you']]})
# Texts: (' And so very you.  You know I say it w/ nothing but love, dude.', ' I love flock on ubuntu', ' thank u, thank u, thank u for everything this weekend!! U guys are AMAZING. I`ll see u again at alpine! Thx for chattin w us 2!', 'thank God we finally found her!')
# Annotations: ({'entities': [[50, 56, 't love']]}, {'entities': [[3, 7, 'love']]}, {'entities': [[57, 128, 'U guys are AMAZING. I`ll see u again at alpine! Thx for chattin w us 2!']]}, {'entities': [[0, 12, 'thank God we']]})
# Texts: ('In about 2 hours from now i will find out how good the STAR TREK Film from J.J. really is. A Ticket costs 9 Euro and i hope its worth it', ' Hey fellow Trojan..congrats on graduation.', ' Good morning MiaMiaDC  My weekend was great and I just had my Monday, which was also great  I hope you have a wonderful day!', 'nothings better then going out for chinese at the supperinn with ma fave cousins at 1am')
# Annotations: ({'entities': [[117, 136, 'i hope its worth it']]}, {'entities': [[19, 43, '.congrats on graduation.']]}, {'entities': [[109, 119, 'a wonderfu']]}, {'entities': [[60, 83, 'with ma fave cousins at']]})
# Texts: ('happy mother`s day to all the moms out there. i hope i never join that crowd', ' OMG, you have curly hair! Too cute!', ' wahahahaha!! i wanna naaaaa!!! well...hapit na i guess. hahahaha ) yes, now we all know!!! hahahaha lol ) NARN! haha joke', '__buckley Good for you mate, sadly I couldnt get pissed tonight **** driving bad times')
# Annotations: ({'entities': [[0, 18, 'happy mother`s day']]}, {'entities': [[27, 36, 'Too cute!']]}, {'entities': [[118, 122, 'joke']]}, {'entities': [[10, 86, 'Good for you mate, sadly I couldnt get pissed tonight **** driving bad times']]})
# Texts: ('. welcome to Twitter!!!    Love you!!!  Can`t wait to see you next month', 'is on the road now! with 7 hours ahead and a beautiful girl behind', ' Too easy! Happy Mother`s Day, to a great mom!', ' I`ll believe it when I see it')
# Annotations: ({'entities': [[27, 34, 'Love yo']]}, {'entities': [[45, 54, 'beautiful']]}, {'entities': [[11, 30, 'Happy Mother`s Day,']]}, {'entities': [[6, 13, 'believe']]})
# Texts: ('FTSK and Mercy Mercedes were amazing tonight.. as always', '2,697 views on my FLickr Account.. Maybe is not much for you...  but I`m happy  ... YAY http://www.flickr.com/photos/bonassin/', '@ Sly party enjoying life  partying tonight.....maybe?', 'Got home from audition awhile ago. I think it went pretty well  Now my math homework is calling my name -.-`')
# Annotations: ({'entities': [[24, 46, 'were amazing tonight..']]}, {'entities': [[67, 87, 't I`m happy  ... YAY']]}, {'entities': [[12, 44, 'enjoying life  partying tonight.']]}, {'entities': [[0, 62, 'Got home from audition awhile ago. I think it went pretty well']]})
# Texts: (' No, nothing so important. I just like it to look like that. It`s an old hairstype actually', '  enjoy ur night', 'ShoesShoesShoes.YayYayYay.lol.IWouldPostATwitPic.ButIdntKnoHow2', ' congrats to the A`s!! ugh, we still have til the end of june')
# Annotations: ({'entities': [[34, 38, 'like']]}, {'entities': [[2, 7, 'enjoy']]}, {'entities': [[0, 31, 'ShoesShoesShoes.YayYayYay.lol.I']]}, {'entities': [[1, 61, 'congrats to the A`s!! ugh, we still have til the end of june']]})
# Texts: ('Just had some strawberries for afternoon snack, I love strawberries!! Gonna make a strawberry smoothie tonight after the gym', ' I appreciate your kind words. I am glad that the words resonate with you', ' what a cute dog', 'Good morning everybody !!')
# Annotations: ({'entities': [[48, 69, 'I love strawberries!!']]}, {'entities': [[36, 40, 'glad']]}, {'entities': [[1, 16, 'what a cute dog']]}, {'entities': [[0, 4, 'Good']]})
# Texts: (' Yay, three followers! Good to know more than one person in this big wide world likes fishies.', '_KHC wooow. lucky XD my break is gonna end. my classes starts @ june 4', 'Had a neat mothers day - nothing flash, just some chillin time with my girls', 'Woke up and it`s bank holiday monday, so no college. got a text from tom via jason`s mobile earlier today, so i`m hoping they turned up.')
# Annotations: ({'entities': [[23, 27, 'Good']]}, {'entities': [[12, 17, 'lucky']]}, {'entities': [[6, 10, 'neat']]}, {'entities': [[110, 136, 'i`m hoping they turned up.']]})
# Texts: (' cant say i havee, im at james` but i did some rs yesterdayy!. im learning my quotess', 'Just watched the movie The Holiday. I had forgotten what a feel good movie it was!  Lovely evening.', ' thanks for the add  I`ll try again signing in later when I get home. If still no such luck then I`ll email someone', '_13 Awe, THX so much! Neither of need 2b sick on Friday!!  Do u have any prayer requests?')
# Annotations: ({'entities': [[61, 85, '. im learning my quotess']]}, {'entities': [[59, 99, 'feel good movie it was!  Lovely evening.']]}, {'entities': [[1, 7, 'thanks']]}, {'entities': [[4, 21, 'Awe, THX so much!']]})
# Texts: (' Aural goodness', 'Sitting in mels house, just finished eating mcdicks, laughing at all the dumb stuff I said tonight!! Ready for bed? I think so', '_Reviews THANKS!', 'Hi this is http://gayorbispace.com We hope everybody is having a safe & fun weekend')
# Annotations: ({'entities': [[7, 15, 'goodness']]}, {'entities': [[53, 85, 'laughing at all the dumb stuff I']]}, {'entities': [[9, 16, 'THANKS!']]}, {'entities': [[38, 42, 'hope']]})
# Texts: (' I`m proud of You Solange.', 'wants to hang out with friends SOON!', 'I lOve this day  No school --> studyin` quietly', ' http://bit.ly/Msize  There you go dear  I love her Janelle')
# Annotations: ({'entities': [[1, 17, 'I`m proud of You']]}, {'entities': [[0, 36, 'wants to hang out with friends SOON!']]}, {'entities': [[2, 6, 'lOve']]}, {'entities': [[41, 46, 'I lov']]})
# Texts: ('http://twitpic.com/4jfkw - AFC! Oh yess', 'saying goodbye to  for a year  she`s been awesome in helping me fit into the team at Veritas!', 'in park slope brooklyn working the bust photoshoot. this is so exciting! &no more fever! but my tonsils are the size of golfballs', ' hahaha probably not  sorry. We`ve got some things to do around the house...and then we have to go to Jared`s parents house')
# Annotations: ({'entities': [[32, 39, 'Oh yess']]}, {'entities': [[31, 49, 'she`s been awesome']]}, {'entities': [[52, 72, 'this is so exciting!']]}, {'entities': [[17, 27, 'not  sorry']]})
# Texts: ('Chocolate milk is so much better through a straw. I lack said straw', 'is anxiously awaiting Rockets-Lakers game ... Yes, I finally got Tix for Games 3 & 4 .... Yeahhhhh', 'Looks like I got a new job', 'Greg back in the top 10. This is why I love Nascar.')
# Annotations: ({'entities': [[0, 49, 'Chocolate milk is so much better through a straw.']]}, {'entities': [[90, 98, 'Yeahhhhh']]}, {'entities': [[0, 26, 'Looks like I got a new job']]}, {'entities': [[39, 43, 'love']]})
# Texts: (' I`m pretty sure my bum shape will still be imprinted there', ' I GOT UR BACK @ BABY!! much love to ya!', ' Thx 4 sharing!', ' Happy Mother`s Day!')
# Annotations: ({'entities': [[1, 16, 'I`m pretty sure']]}, {'entities': [[24, 40, 'much love to ya!']]}, {'entities': [[1, 4, 'Thx']]}, {'entities': [[1, 6, 'Happy']]})
# Texts: ('  sounds like a challenge then  I can see it would be useful to be able explicitly  schedule threads...', ' yeah i checked it, pretty nice site', ' I just added a butt to your name in my phone after I made you go home in the cold. Because I love you!', ' good luck going to sleep. i`m up working on a stupid paper. no worries. ur not alone.  so u ready to record that album or what?')
# Annotations: ({'entities': [[51, 59, 'be usefu']]}, {'entities': [[27, 31, 'nice']]}, {'entities': [[90, 103, 'e I love you!']]}, {'entities': [[1, 10, 'good luck']]})
# Texts: ('Loved the sun today. Did not love a black suit and black top plus 6 trains/tubes to get to my meeting and back  Need to shop for summer', ' thanks babe. I guess I will find the right person one day, til then I`m better off alone', ' In the end the magic of `And so to dream` wins, along with swaying back and forth within site of a sleeping mommy.', ' Goodnight!!!!!!')
# Annotations: ({'entities': [[0, 5, 'Loved']]}, {'entities': [[1, 7, 'thanks']]}, {'entities': [[43, 48, 'wins,']]}, {'entities': [[1, 11, 'Goodnight!']]})
# Texts: (' cool thanks for the response.  I`ll check out that Firefox!', '  anything I can do to help?', ' wishing you were here too babe.. we`d have a ball', ' Wow! Some person u are!')
# Annotations: ({'entities': [[1, 12, 'cool thanks']]}, {'entities': [[21, 27, 'o help']]}, {'entities': [[1, 8, 'wishing']]}, {'entities': [[1, 5, 'Wow!']]})
# Texts: ('happy star wars dayyyy =D and hbd to uncle LEE', '_Janeway OOC: Goodnight', 'morning darlin`  Hope you`re feelin` tip-top  ? http://blip.fm/~5z7zs', 'Typical overcast bank holiday Monday, glad we went to the beach on Saturday')
# Annotations: ({'entities': [[0, 22, 'happy star wars dayyyy']]}, {'entities': [[14, 23, 'Goodnight']]}, {'entities': [[0, 44, 'morning darlin`  Hope you`re feelin` tip-top']]}, {'entities': [[38, 42, 'glad']]})
# Texts: ('All of you can have fun tweeting all day while im cleaning hair  LOL', 'Goodnight world and all who inhabit it!', 'OMJ! The 3rd episode of Jonas is too great! They are so funny. I wish I was the Pizza Girll. Lol <3', ' ironclad determination?')
# Annotations: ({'entities': [[20, 23, 'fun']]}, {'entities': [[0, 9, 'Goodnight']]}, {'entities': [[37, 43, 'great!']]}, {'entities': [[1, 24, 'ironclad determination?']]})
# Texts: (' Aww nice', 'i can`t stop listening to  new single! (paranoid) it`s so amazing. i love them.', 'excited for YSJ Summer Ball - I wish we had one too', ' they look nice atleast  haha. <3')
# Annotations: ({'entities': [[1, 9, 'Aww nice']]}, {'entities': [[58, 66, 'amazing.']]}, {'entities': [[32, 36, 'wish']]}, {'entities': [[1, 15, 'they look nice']]})
# Texts: (' Thabks! This made me feel very special!', 'loving my new tv', '_lottie Not one of my favourite pastimes  This weekend is a long weekend here so Monday I`m off to an Ice Show w/ the G/daughter ;)', ' hey chocolate chips is good.  i want a snack too but i`m out of snacks.')
# Annotations: ({'entities': [[32, 40, 'special!']]}, {'entities': [[0, 16, 'loving my new tv']]}, {'entities': [[22, 31, 'favourite']]}, {'entities': [[24, 29, 'good.']]})
# Texts: ('..but did i mention spending time with two bffs .. Totally worth it', 'amazing, my brand new PARI neb broke. go figure. and it`s the weekend. looks like i won`t be getting another one until next week.  *sigh*', ' Thanks, Nick. Means a lot coming from a designer of your caliber  #symphonycms', 'going to eat some pasta bake, my favourite food! later going to the flea market  you`re my lilime')
# Annotations: ({'entities': [[51, 67, 'Totally worth it']]}, {'entities': [[0, 8, 'amazing,']]}, {'entities': [[1, 8, 'Thanks,']]}, {'entities': [[30, 48, 'my favourite food!']]})
# Texts: ('Friends are gone. Sushi, movies, laughter. Just what I needed. FUN!', ' I feel for you  I hope it`s a smooth flight. Be safe! Mucho amor from Boston!', 'Tiesto in Vicky Park - how excellent', 'NiGHT NiGHT MY TWiTTER LOVES ON THE PHONE THEN SLEEP')
# Annotations: ({'entities': [[63, 67, 'FUN!']]}, {'entities': [[1, 53, 'I feel for you  I hope it`s a smooth flight. Be safe']]}, {'entities': [[27, 36, 'excellent']]}, {'entities': [[0, 52, 'NiGHT NiGHT MY TWiTTER LOVES ON THE PHONE THEN SLEEP']]})
# Texts: (' hes definitely my fav host ever!  Can`t wait to watch the rest tomorrow!!', 'Sitting waiting for dough to rise. There`s something about it that calms me down. Maybe the knowledge that I`ll have cinnamon rolls soon', '_30439 I really wish I could go!', 'Oh no! My kindergarten teacher died  Mrs. Collinson always remembered every student she ever had. Loved that lady.')
# Annotations: ({'entities': [[16, 33, 'my fav host ever!']]}, {'entities': [[67, 81, 'calms me down.']]}, {'entities': [[16, 20, 'wish']]}, {'entities': [[98, 114, 'Loved that lady.']]})
#   0%|                                                                                                                                                                            | 0/2 [00:12<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-06063fe0e61f> in <module>
# ----> 1 train(train_data, model_path, n_iter=2, model=None)
#
# <ipython-input-12-cbb818ef71da> in train(train_data, output_dir, n_iter, model)
#      41                 print(f"Texts: {texts}")
#      42                 print(f"Annotations: {annotations}")
# ---> 43                 nlp.update(
#      44                     texts,  # batch of texts
#      45                     annotations,  # batch of annotations
#
# c:\users\mbergman\appdata\local\continuum\anaconda3\envs\twitter\lib\site-packages\spacy\language.py in update(self, docs, golds, drop, sgd, losses, component_cfg)
#     519             proc.update(docs, golds, sgd=get_grads, losses=losses, **kwargs)
#     520             for key, (W, dW) in grads.items():
# --> 521                 sgd(W, dW, key=key)
#     522
#     523     def rehearse(self, docs, sgd=None, losses=None, config=None):
#
# KeyboardInterrupt:
